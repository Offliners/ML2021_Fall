# %% [markdown]
# <a href="https://colab.research.google.com/github/Offliners/HTML_2021Fall/blob/main/Final%20Project/final_project_test3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Directory**
#
# ```
# data_dir
#     ├── data
#     │   ├── Test_IDs.csv
#     │   ├── ...
#     │   ├── status.csv
#     ├── statistics
#     │   ├── Churn Category_stat.png
#     │   ├── ...
#     │   ├── miss rate_stat.png
# ```

# %% [markdown]
# # **Display information of GPU**

# %%
# !nvidia-smi
# Out:
# Mon Jan 17 06:58:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # **Download Dataset**

# %%
# !mkdir "./data"
# !mkdir "./statistics"
# !gdown --id 1X5yz7QLAu4nttnCea4ALf6alae6Clv_o --output "./data/dataset.zip"
# !unzip -q "./data/dataset.zip" -d "./data"
# !rm "./data/dataset.zip"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X5yz7QLAu4nttnCea4ALf6alae6Clv_o
# To: /content/data/dataset.zip
# 100% 660k/660k [00:00<00:00, 97.4MB/s]

# %% [markdown]
# # **Import Some Packages**

# %%
import time
import numpy as np
import pandas as pd
from glob import glob
from collections import Counter
import collections
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report, plot_confusion_matrix
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# SMOTE
from imblearn.over_sampling import SMOTE, ADASYN, SVMSMOTE, BorderlineSMOTE, SMOTEN

# SVM
from sklearn.svm import SVC

# DNN
import torch
import torch.nn as nn
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from torchsummary import summary
from torch.optim.lr_scheduler import StepLR

# XGBoost
from xgboost import XGBClassifier

# %% [markdown]
# # **Set a Random Seed**

# %%
# Set a random seed for reproducibility
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # **CSV Files Combination**

# %%
train_path = './data/Train_IDs.csv'  # path to training data
test_path = './data/Test_IDs.csv'    # path to testing data

files = glob('./data/*.csv')
data_csv = []
data_csv.append(train_path)
for csv in files:
    if ('IDs' not in csv) and ('sample' not in csv) and ('population' not in csv) and ('result' not in csv):
        data_csv.append(csv)
  
print(data_csv)
df_list = [pd.read_csv(file) for file in data_csv]
# Out:
# ['./data/Train_IDs.csv', './data/services.csv', './data/location.csv', './data/satisfaction.csv', './data/demographics.csv', './data/status.csv']

# %%
result_total = df_list[0]
for df in df_list[1:]:
    result_total = pd.merge(result_total, df, how='outer', on='Customer ID')

result_total.to_csv('./data/result_total.csv') # Save combined all result to result_total.csv

# %%
# There are 7043 total customer data
print(result_total)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     0650-BWOZN      1.0  ...                  0.0     Competitor
# 1     0562-FGDCR      1.0  ...                  0.0     Competitor
# 2     6688-UZPWD      1.0  ...                  NaN       No Churn
# 3     2905-KFQUV      1.0  ...                  0.0     Competitor
# 4     9720-JJJOR      1.0  ...                  0.0       No Churn
# ...          ...      ...  ...                  ...            ...
# 7038  6778-EICRF      NaN  ...                  0.0            NaN
# 7039  0772-GYEQQ      NaN  ...                  2.0            NaN
# 7040  5666-CYCYZ      NaN  ...                  0.0            NaN
# 7041  4893-GYUJU      NaN  ...                  0.0            NaN
# 7042  3426-NIYYL      NaN  ...                  2.0            NaN
#
# [7043 rows x 48 columns]

# %%
# Train_IDs has 5634 customer data
result_train_total = df_list[0]
for df in df_list[1:]:
    result_train_total = pd.merge(result_train_total, df, how='left', on='Customer ID')

print(result_train_total)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     0650-BWOZN      1.0  ...                  0.0     Competitor
# 1     0562-FGDCR      1.0  ...                  0.0     Competitor
# 2     6688-UZPWD      1.0  ...                  NaN       No Churn
# 3     2905-KFQUV      1.0  ...                  0.0     Competitor
# 4     9720-JJJOR      1.0  ...                  0.0       No Churn
# ...          ...      ...  ...                  ...            ...
# 5629  1178-PZGAB      1.0  ...                  0.0            NaN
# 5630  4806-KEXQR      1.0  ...                  0.0            NaN
# 5631  8809-RIHDD      1.0  ...                  2.0       No Churn
# 5632  6663-JOCQO      1.0  ...                  3.0       No Churn
# 5633  7010-ZMVBF      1.0  ...                  0.0       No Churn
#
# [5634 rows x 48 columns]

# %%
# Train_IDs has 4226 customer data with label
result_train = df_list[0]
for df in df_list[1:]:
    result_train = pd.merge(result_train, df, how='right', on='Customer ID')

print(result_train)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     0650-BWOZN      NaN  ...                  0.0     Competitor
# 1     0562-FGDCR      1.0  ...                  0.0     Competitor
# 2     6688-UZPWD      1.0  ...                  NaN       No Churn
# 3     2905-KFQUV      1.0  ...                  0.0     Competitor
# 4     9720-JJJOR      NaN  ...                  0.0       No Churn
# ...          ...      ...  ...                  ...            ...
# 4221  3313-QKNKB      NaN  ...                  NaN       No Churn
# 4222  8668-KNZTI      NaN  ...                  NaN       No Churn
# 4223  8809-RIHDD      NaN  ...                  2.0       No Churn
# 4224  6663-JOCQO      NaN  ...                  3.0       No Churn
# 4225  7010-ZMVBF      1.0  ...                  0.0       No Churn
#
# [4226 rows x 48 columns]

# %%
# Train_IDs has 1408 customer data without label
result_train_miss = df_list[0]
for df in df_list[1:]:
    result_train_miss = pd.merge(result_train_miss, df, how='left', on='Customer ID')

result_train_miss = result_train_miss[result_train_miss['Churn Category'].isna()]

print(result_train_miss)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 6     0394-YONDK      1.0  ...                  NaN            NaN
# 7     0396-HUJBP      1.0  ...                  0.0            NaN
# 11    0684-AOSIH      1.0  ...                  2.0            NaN
# 14    1679-JRFBR      1.0  ...                  0.0            NaN
# 18    5533-NHFRF      NaN  ...                  0.0            NaN
# ...          ...      ...  ...                  ...            ...
# 5603  6330-JKLPC      1.0  ...                  NaN            NaN
# 5618  4549-ZDQYY      NaN  ...                  0.0            NaN
# 5622  9127-QRZMH      1.0  ...                  0.0            NaN
# 5629  1178-PZGAB      1.0  ...                  0.0            NaN
# 5630  4806-KEXQR      1.0  ...                  0.0            NaN
#
# [1408 rows x 48 columns]

# %%
# Test_Ids has 1409 customer data
df_test = pd.read_csv(test_path)
result_test = df_test
for df in df_list[1:]:
    result_test = pd.merge(result_test, df, how='left', on='Customer ID')

print(result_test)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     9938-EKRGF      1.0  ...                  0.0            NaN
# 1     7379-POKDZ      1.0  ...                  0.0            NaN
# 2     0654-HMSHN      1.0  ...                  NaN            NaN
# 3     2045-BMBTJ      1.0  ...                  3.0            NaN
# 4     0701-TJSEF      1.0  ...                  0.0            NaN
# ...          ...      ...  ...                  ...            ...
# 1404  4587-VVTOX      1.0  ...                  NaN            NaN
# 1405  7716-YTYHG      NaN  ...                  0.0            NaN
# 1406  7649-PHJVR      NaN  ...                  0.0            NaN
# 1407  7855-DIWPO      1.0  ...                  3.0            NaN
# 1408  8197-BFWVU      1.0  ...                  NaN            NaN
#
# [1409 rows x 48 columns]

# %%
print(result_total.dropna()) # Find customer with full data infomation
# Out:
#      Customer ID  Count_x  ... Number of Dependents   Churn Category
# 666   0454-OKRCT      1.0  ...                  2.0         No Churn
# 678   1735-XMJVH      1.0  ...                  0.0         No Churn
# 1799  1245-HARPS      1.0  ...                  0.0  Dissatisfaction
# 2805  8445-DNBAE      1.0  ...                  0.0       Competitor
# 2883  8708-XPXHZ      1.0  ...                  0.0         No Churn
# 3062  9522-ZSINC      1.0  ...                  0.0         No Churn
# 4297  0836-SEYLU      1.0  ...                  0.0         No Churn
# 5146  7274-RTAPZ      1.0  ...                  1.0         No Churn
#
# [8 rows x 48 columns]

# %%
result_cols = result_total.columns
print(result_cols)
# Out:
# Index(['Customer ID', 'Count_x', 'Quarter', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Count_y', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Satisfaction Score', 'Count',
#        'Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
#        'Number of Dependents', 'Churn Category'],
#       dtype='object')

# %%
missing = result_train_total.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_train_total.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of training dataset')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 0.8])  
plt.savefig(f'./statistics/miss rate_train_stat.png')  
plt.show()
plt.close()

# %%
missing = result_train.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_train.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of training dataset with label')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 0.8])  
plt.savefig(f'./statistics/miss rate_train_stat.png')  
plt.show()
plt.close()

# %%
missing = result_train_miss.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_train_miss.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of training dataset without label')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 1.4])  
plt.savefig(f'./statistics/miss rate_train_stat.png')  
plt.show()
plt.close()

# %%
missing = result_test.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_test.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of test dataset')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 1.4])  
plt.savefig(f'./statistics/miss rate_test_stat.png')  
plt.show()
plt.close()

# %% [markdown]
# # **Statistics and Data Preprocessing**

# %%
result_train_total_copy = result_train_total.copy(deep=True)
result_train_copy = result_train.copy(deep=True)
result_train_miss_copy = result_train_miss.copy(deep=True)
result_test_copy = result_test.copy(deep=True)
def label_statistics(label):
    freq = result_train_total.groupby(label).size()

    names = [name for name, _ in freq.items()]
    names.append('Nan')
    counts = [count for _, count in freq.items()]
    counts.append(len(result_train[label]) - sum(counts))

    fig = plt.figure(figsize=(8, 6))
    x = np.arange(len(names))
    plt.bar(x, counts)
    plt.xticks(x, names, rotation=15)
    plt.title(f'Statistics of {label}')
    plt.savefig(f'./statistics/Statistics of {label}.png')
    print(f'Statistics of {label}.png saved')
    plt.close()

# %%
need_statistics_col = ['Churn Category', 'Satisfaction Score', 
       'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
       'Number of Dependents', 'Country', 'State', 'City', 'Quarter',
       'Referred a Friend', 'Number of Referrals', 'Offer',
       'Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type',
       'Online Security', 'Online Backup', 'Device Protection Plan',
       'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
       'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
       'Payment Method', 'Zip Code']

# Replace NaN with the most frequent label
for need_col in need_statistics_col:
    label_statistics(need_col)

    # Encode target labels with value
    le = LabelEncoder()
    result_train_copy[need_col] = le.fit_transform(result_train_copy[need_col])

    if need_col == 'Churn Category':
        encoder_map = dict(zip(le.classes_, le.transform(le.classes_)))
    
    result_train_miss_copy[need_col] = le.fit_transform(result_train_miss_copy[need_col])
    result_test_copy[need_col] = le.fit_transform(result_test_copy[need_col])
# Out:
# Statistics of Churn Category.png saved
# Statistics of Satisfaction Score.png saved
# Statistics of Gender.png saved
# Statistics of Under 30.png saved
# Statistics of Senior Citizen.png saved
# Statistics of Married.png saved
# Statistics of Dependents.png saved
# Statistics of Number of Dependents.png saved
# Statistics of Country.png saved
# Statistics of State.png saved
# Statistics of City.png saved
# Statistics of Quarter.png saved
# Statistics of Referred a Friend.png saved
# Statistics of Number of Referrals.png saved
# Statistics of Offer.png saved
# Statistics of Phone Service.png saved
# Statistics of Multiple Lines.png saved
# Statistics of Internet Service.png saved
# Statistics of Internet Type.png saved
# Statistics of Online Security.png saved
# Statistics of Online Backup.png saved
# Statistics of Device Protection Plan.png saved
# Statistics of Premium Tech Support.png saved
# Statistics of Streaming TV.png saved
# Statistics of Streaming Movies.png saved
# Statistics of Streaming Music.png saved
# Statistics of Unlimited Data.png saved
# Statistics of Contract.png saved
# Statistics of Paperless Billing.png saved
# Statistics of Payment Method.png saved
# Statistics of Zip Code.png saved

# %%
population = pd.read_csv('./data/population.csv')
population = population.drop('Zip Code', axis=1)
population.rename({'ID':'Zip Code'}, axis=1, inplace=True)
result_train_copy = pd.merge(result_train_copy, population, how='left', on='Zip Code')
result_train_miss_copy = pd.merge(result_train_miss_copy, population, how='left', on='Zip Code')
result_test_copy = pd.merge(result_test_copy, population, how='left', on='Zip Code')

need_avg_col = [item for item in result_cols if item not in need_statistics_col]
need_avg_col.append('Population')

def data_imputation(train_dataset, miss_dataset, test_dataset, target):
    imputer = IterativeImputer(max_iter=10, initial_strategy='median', random_state=seed)
    # imputer = KNNImputer(n_neighbors=5, weights='distance')
    imputer.fit(train_dataset)
    train_dataset = imputer.transform(train_dataset)
    miss_dataset = imputer.transform(miss_dataset)
    test_dataset = imputer.transform(test_dataset)

    train_dataset = pd.DataFrame(train_dataset, columns=target)
    miss_dataset = pd.DataFrame(miss_dataset, columns=target)
    test_dataset = pd.DataFrame(test_dataset, columns=target)

    return train_dataset, miss_dataset, test_dataset

col_names = list(result_cols.values)
col_names.remove('Customer ID')
col_names.remove('Lat Long')
col_names.remove('Churn Category')
col_names.append('Population')

result_train_copy[col_names], result_train_miss_copy[col_names], result_test_copy[col_names] = data_imputation(result_train_copy[col_names], result_train_miss_copy[col_names], result_test_copy[col_names], col_names)

# %%
result_train_copy = result_train_copy.drop('Customer ID', axis=1)
result_train_copy = result_train_copy.drop('Lat Long', axis=1)
result_train_miss_copy = result_train_miss_copy.drop('Customer ID', axis=1)
result_train_miss_copy = result_train_miss_copy.drop('Lat Long', axis=1)
result_test_copy = result_test_copy.drop('Customer ID', axis=1)
result_test_copy = result_test_copy.drop('Lat Long', axis=1)

print(result_train_copy)
# Out:
#       Count_x  Quarter  ...  Churn Category  Population
# 0         1.0      1.0  ...               1       660.0
# 1         1.0      0.0  ...               1     37280.0
# 2         1.0      0.0  ...               3      2899.0
# 3         1.0      0.0  ...               1     26831.0
# 4         1.0      1.0  ...               3       660.0
# ...       ...      ...  ...             ...         ...
# 4221      1.0      1.0  ...               3       660.0
# 4222      1.0      1.0  ...               3       660.0
# 4223      1.0      1.0  ...               3       660.0
# 4224      1.0      1.0  ...               3       660.0
# 4225      1.0      0.0  ...               3     27047.0
#
# [4226 rows x 47 columns]

# %%
# Find the correlation of columns
cor_matrix = result_train_copy.corr().abs()
print(cor_matrix['Churn Category'])
# Out:
# Count_x                                   NaN
# Quarter                              0.026687
# Referred a Friend                    0.034992
# Number of Referrals                  0.065368
# Tenure in Months                     0.150018
# Offer                                0.035282
# Phone Service                        0.004287
# Avg Monthly Long Distance Charges    0.010180
# Multiple Lines                       0.021953
# Internet Service                     0.021609
# Internet Type                        0.038484
# Avg Monthly GB Download              0.024364
# Online Security                      0.061089
# Online Backup                        0.031315
# Device Protection Plan               0.028059
# Premium Tech Support                 0.053844
# Streaming TV                         0.008534
# Streaming Movies                     0.000321
# Streaming Music                      0.015176
# Unlimited Data                       0.013768
# Contract                             0.111203
# Paperless Billing                    0.009588
# Payment Method                       0.048995
# Monthly Charge                       0.050043
# Total Charges                        0.098140
# Total Refunds                        0.017651
# Total Extra Data Charges             0.024630
# Total Long Distance Charges          0.110037
# Total Revenue                        0.110460
# Count_y                                   NaN
# Country                              0.043073
# State                                0.054701
# City                                 0.035223
# Zip Code                             0.045957
# Latitude                             0.088238
# Longitude                            0.062988
# Satisfaction Score                   0.248098
# Count                                     NaN
# Gender                               0.005451
# Age                                  0.068289
# Under 30                             0.043659
# Senior Citizen                       0.004644
# Married                              0.037126
# Dependents                           0.087645
# Number of Dependents                 0.052063
# Churn Category                       1.000000
# Population                           0.014188
# Name: Churn Category, dtype: float64

# %%
plt.figure(figsize=(17, 13))
cor_matrix_copy = cor_matrix.copy(deep=True)
cor_matrix_copy.dropna()
ax = sns.heatmap(cor_matrix_copy, xticklabels=cor_matrix_copy.columns, yticklabels=cor_matrix_copy.columns, 
                 linewidths=0.2, cmap="RdYlGn_r", fmt="s")

plt.title("Correlation between variables")
plt.show()

# %%
useless_feature = [index for index, value in cor_matrix['Churn Category'].items() if value < 0.05 or pd.isnull(value)]
print(useless_feature)
# Out:
# ['Count_x', 'Quarter', 'Referred a Friend', 'Offer', 'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Avg Monthly GB Download', 'Online Backup', 'Device Protection Plan', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Paperless Billing', 'Payment Method', 'Total Refunds', 'Total Extra Data Charges', 'Count_y', 'Country', 'City', 'Zip Code', 'Count', 'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Population']

# %%
def dropColumns(label):
    global result_train_copy, result_train_miss_copy, result_test_copy
    result_train_copy = result_train_copy.drop(label, axis=1)
    result_train_miss_copy = result_train_miss_copy.drop(label, axis=1)
    result_test_copy = result_test_copy.drop(label, axis=1)

# %%
# Throw away the data columns whose correlation to Churn Category is less than 0.05
for item in useless_feature:
    dropColumns(item)

# %%
result_train_copy.to_csv('./data/result_after_preprocessing.csv') # Save after preprocessing result to result_after_preprocessing.csv
feature_amount = len(result_train_copy.columns)

print(result_train_copy)
print(result_train_miss_copy)
print(result_test_copy)
# Out:
#       Number of Referrals  ...  Churn Category
# 0                    11.0  ...               1
# 1                     0.0  ...               1
# 2                     4.0  ...               3
# 3                     0.0  ...               1
# 4                    11.0  ...               3
# ...                   ...  ...             ...
# 4221                 11.0  ...               3
# 4222                 11.0  ...               3
# 4223                 11.0  ...               3
# 4224                 11.0  ...               3
# 4225                  8.0  ...               3
#
# [4226 rows x 17 columns]
#       Number of Referrals  ...  Churn Category
# 0                     0.0  ...               0
# 1                     2.0  ...               0
# 2                     1.0  ...               0
# 3                    10.0  ...               0
# 4                     0.0  ...               0
# ...                   ...  ...             ...
# 1403                  0.0  ...               0
# 1404                 12.0  ...               0
# 1405                  9.0  ...               0
# 1406                  0.0  ...               0
# 1407                  0.0  ...               0
#
# [1408 rows x 17 columns]
#       Number of Referrals  ...  Churn Category
# 0                     1.0  ...               0
# 1                     0.0  ...               0
# 2                     9.0  ...               0
# 3                     1.0  ...               0
# 4                     1.0  ...               0
# ...                   ...  ...             ...
# 1404                  0.0  ...               0
# 1405                 11.0  ...               0
# 1406                  1.0  ...               0
# 1407                  1.0  ...               0
# 1408                  0.0  ...               0
#
# [1409 rows x 17 columns]

# %% [markdown]
# # **Balance Data**

# %%
y_train = result_train_copy['Churn Category'].values
X_train = result_train_copy.drop('Churn Category', axis=1)

X_train_miss = result_train_miss_copy.drop('Churn Category', axis=1)

# %%
print(f"normal data distribution: {Counter(y_train)}")

# SMOTE
# smo = SMOTE(random_state=seed)
# X_train, y_train = smo.fit_resample(X_train, y_train)

# print(f"SMOTE data distribution: {Counter(y_train)}")

# SVMSMOTE
# ssmo = SVMSMOTE(random_state=seed)
# X_train, y_train = ssmo.fit_resample(X_train, y_train)

# print(f"SVMSMOTE data distribution: {Counter(y_train)}")

# SMOTEN
smn = SMOTEN(random_state=seed)
X_train, y_train = smn.fit_resample(X_train, y_train)

print(f"SMOTEN data distribution: {Counter(y_train)}")

# BorderlineSMOTE
# bsmo = BorderlineSMOTE(random_state=seed)
# X_train, y_train = bsmo.fit_resample(X_train, y_train)

# print(f"BorderlineSMOTE data distribution: {Counter(y_train)}")

# ADASYN
# ada = ADASYN(random_state=seed)
# X_train, y_train = ada.fit_resample(X_train, y_train)

# print(f"ADASYN data distribution: {Counter(y_train)}")

class_weight = dict(Counter(y_train))
# Out:
# normal data distribution: Counter({3: 3118, 1: 490, 0: 201, 2: 177, 5: 124, 4: 116})
# SMOTEN data distribution: Counter({1: 3118, 3: 3118, 2: 3118, 4: 3118, 5: 3118, 0: 3118})

# %% [markdown]
# # **Split and Standardize Data**

# %%
train_x, val_x, train_y, val_y = train_test_split(X_train, y_train, test_size=0.2, random_state=seed)

ss = StandardScaler().fit(train_x)
train_x = ss.transform(train_x)
val_x = ss.transform(val_x)
miss_x = ss.transform(X_train_miss)

X_test = result_test_copy.drop('Churn Category', axis=1)
X_test_std = ss.transform(X_test)

class_weight = {k: train_x.shape[0] / v for k, v in class_weight.items()}
class_weight = collections.OrderedDict(sorted(class_weight.items()))
print(class_weight)
# Out:
# OrderedDict([(0, 4.799871712636305), (1, 4.799871712636305), (2, 4.799871712636305), (3, 4.799871712636305), (4, 4.799871712636305), (5, 4.799871712636305)])

# %% [markdown]
# # **SVM Train**

# %%
svm = SVC(kernel='rbf', gamma=0.1, C=10, class_weight=class_weight)

start_time = time.time()
model = svm.fit(train_x, train_y)
end_time = time.time()

print(f'Training use {round(end_time - start_time, 3)}s')
# Out:
# Training use 10.304s

# %%
y_train_predict = svm.predict(train_x)
Ein = np.mean(np.array(y_train_predict) != train_y)
F1in = metrics.f1_score(train_y, y_train_predict, average='macro')  
print(f'Ein = {round(Ein, 5)}')
print(f'F1_in = {round(F1in, 5)}')

y_val_predict = svm.predict(val_x)
Eval = np.mean(np.array(y_val_predict) != val_y)
F1val = metrics.f1_score(val_y, y_val_predict, average='macro')  
print(f'Eval = {round(Eval, 5)}')
print(f'F1_val = {round(F1val, 5)}')
# Out:
# Ein = 0.15896
# F1_in = 0.84637
# Eval = 0.19161
# F1_val = 0.81219

# %%
plot_confusion_matrix(model, train_x, train_y)
plot_confusion_matrix(model, val_x, val_y)
print(encoder_map)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}

# %%
print(classification_report(train_y, y_train_predict))
print(classification_report(val_y, y_val_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84      2485
#            1       0.90      0.79      0.85      2514
#            2       0.95      0.83      0.88      2456
#            3       0.96      0.84      0.89      2502
#            4       0.90      0.82      0.86      2523
#            5       0.62      0.97      0.75      2486
#
#     accuracy                           0.84     14966
#    macro avg       0.87      0.84      0.85     14966
# weighted avg       0.87      0.84      0.85     14966
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79       633
#            1       0.84      0.74      0.78       604
#            2       0.95      0.79      0.86       662
#            3       0.89      0.80      0.84       616
#            4       0.88      0.81      0.84       595
#            5       0.61      0.97      0.75       632
#
#     accuracy                           0.81      3742
#    macro avg       0.84      0.81      0.81      3742
# weighted avg       0.84      0.81      0.81      3742

# %% [markdown]
# # **SVM Test**

# %%
y_test = svm.predict(X_test_std)
plot_confusion_matrix(model, X_test_std, y_test)
print(encoder_map)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}

# %%
svm_submit_result = './svm_result.csv'

new_encoder_map = {'No Churn':0, 'Competitor': 1, 'Dissatisfaction':2, 'Attitude': 3, 'Price':4, 'Other':5}

with open(svm_submit_result, 'w') as f:
    f.write('Customer ID,Churn Category\n')
    for i in range(len(df_test.values)):
        id = str(df_test.values[i]).replace('[\'', '')
        id = id.replace('\']', '')
        pred = new_encoder_map.get(list(encoder_map.keys())[list(encoder_map.values()).index(y_test[i])])
        f.write(f'{id},{pred}\n')

# %%
from google.colab import files

files.download(svm_submit_result)

# %% [markdown]
# # **Deep Neural Network Train**

# %%
class IBMDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int)
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.layer1 = nn.Linear(feature_amount - 1, 256)
        self.layer2 = nn.Linear(256, 64)
        self.bn1 = nn.BatchNorm1d(256)
        self.bn2 = nn.BatchNorm1d(64)
        self.out = nn.Linear(64, 6)
        self.dp = nn.Dropout(0.1)
        self.act_fn = nn.LeakyReLU()

    def forward(self, x):
        x = self.layer1(x)
        x = self.act_fn(x)
        x = self.bn1(x)
        x = self.dp(x)

        x = self.layer2(x)
        x = self.act_fn(x)
        x = self.bn2(x)
        x = self.dp(x)
        
        x = self.out(x)
        
        return x

# classifier = Classifier()
# summary(classifier, X_train.shape, device="cpu")

# %%
def get_pseudo_labels(dataset, model, batch_size, threshold=0.99):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    model.eval()
    softmax = nn.Softmax(dim=-1)

    pseudo_x = []
    pseudo_y = []
    for i, data in enumerate(data_loader):
        inputs = data

        with torch.no_grad():
            logits = model(inputs.to(device))

        probs = softmax(logits)
        label = torch.where(torch.max(probs, dim=1)[0] > threshold, torch.argmax(probs,dim=1), -1)
        label = label.cpu()
        for j in range(len(label)):
            if label[j] != -1:
                pseudo_x.append(data[j])
                pseudo_y.append(label[j])

    model.train()
    print(f"Pseudo Labeling : {len(pseudo_x)}")
    if len(pseudo_x) > 0:
        flag = 1
        pseudo_dataset = IBMDataset(torch.stack(pseudo_x, dim=0).numpy(), np.array(pseudo_y))
        return pseudo_dataset, len(pseudo_x), flag
    else:
        flag = 0
        return None, 0, flag

# %%
VAL_RATIO = 0.2
BATCH_SIZE = 64

percent = int(X_train.shape[0] * (1 - VAL_RATIO))
train_x, train_y, val_x, val_y = X_train[:percent], y_train[:percent], X_train[percent:], y_train[percent:]

ss = StandardScaler().fit(train_x)
train_x = ss.transform(train_x)
miss_x = ss.transform(X_train_miss)
val_x = ss.transform(val_x)
X_test_std = ss.transform(X_test)

print('Size of training set: {}'.format(train_x.shape))
print('Size of training set: {}'.format(miss_x.shape))
print('Size of validation set: {}'.format(val_x.shape))
# Out:
# Size of training set: (14966, 16)
# Size of training set: (1408, 16)
# Size of validation set: (3742, 16)

# %%
train_set = IBMDataset(train_x, train_y)
miss_set = IBMDataset(miss_x, None)
val_set = IBMDataset(val_x, val_y)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) # only shuffle the training data
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# %%
# get device 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'DEVICE: {device}')

# training parameters
num_epoch = 3000             # number of training epoch
learning_rate = 0.001       # learning rate
callback_num = 200

# the path where checkpoint saved
model_path = './best_model.ckpt'

# create model, define a loss function, and optimizer
model = Classifier().to(device)
class_weight = [v for k, v in class_weight.items()]
criterion = nn.CrossEntropyLoss(weight=torch.FloatTensor(class_weight).to(device))
optimizer = torch.optim.Adam(model.parameters(), weight_decay=5e-4, lr=learning_rate)
scheduler = StepLR(optimizer, step_size=len(train_loader) * 100, gamma=0.1)
# Out:
# DEVICE: cuda

# %%
best_acc = 0.0
count = 0
start_time = time.time()
train_acc_list = []
train_loss_list = []
val_acc_list = []
val_loss_list = []
for epoch in range(num_epoch):
    train_acc = 0.0
    train_loss = 0.0
    val_acc = 0.0
    val_loss = 0.0

    # Pseudo Label
    pseudo_set, add_num, flag = get_pseudo_labels(miss_set, model, BATCH_SIZE)
    if flag:
        concat_dataset = ConcatDataset([train_set, pseudo_set])
        train_loader_semi = DataLoader(concat_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    else:
        train_loader_semi = train_loader
    # train_loader_semi = train_loader
    # training
    model.train() # set the model to training mode
    for i, data in enumerate(train_loader_semi):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        batch_loss = criterion(outputs, labels)
        _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
        batch_loss.backward() 
        optimizer.step()
        scheduler.step()

        train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
        train_loss += batch_loss.item()

    # validation
    if len(val_set) > 0:
        model.eval() # set the model to evaluation mode
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                batch_loss = criterion(outputs, labels) 
                _, val_pred = torch.max(outputs, 1) 
            
                val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                val_loss += batch_loss.item()

            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/(len(train_set) + add_num), train_loss/len(train_loader_semi), val_acc/len(val_set), val_loss/len(val_loader)
            ))

            # Record Training and validation info
            train_acc_list.append(train_acc/(len(train_set) + add_num))
            train_loss_list.append(train_loss/len(train_loader_semi))
            val_acc_list.append(val_acc/len(val_set))
            val_loss_list.append(val_loss/len(val_loader))

            # if the model improves, save a checkpoint at this epoch
            count += 1
            if val_acc > best_acc:
                count = 0
                best_acc = val_acc
                torch.save(model.state_dict(), model_path)
                print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))
    else:
        print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
            epoch + 1, num_epoch, train_acc/(len(train_set) + add_num), train_loss/len(train_loader_semi)
        ))

    if count > callback_num:
        break

# if not validating, save the last epoch
if len(val_set) == 0:
    torch.save(model.state_dict(), model_path)
    print('saving model at last epoch')

end_time = time.time()
# Out:
# Pseudo Labeling : 0
# [001/3000] Train Acc: 0.546906 Loss: 1.202927 | Val Acc: 0.098878 loss: 2.897894
# saving model with acc 0.099
# Pseudo Labeling : 31
# [002/3000] Train Acc: 0.646529 Loss: 0.921923 | Val Acc: 0.130412 loss: 3.568532
# saving model with acc 0.130
# Pseudo Labeling : 87
# [003/3000] Train Acc: 0.677805 Loss: 0.826768 | Val Acc: 0.129343 loss: 3.959643
# Pseudo Labeling : 78
# [004/3000] Train Acc: 0.694430 Loss: 0.781730 | Val Acc: 0.154463 loss: 4.048907
# saving model with acc 0.154
# Pseudo Labeling : 100
# [005/3000] Train Acc: 0.707022 Loss: 0.748456 | Val Acc: 0.149385 loss: 4.315780
# Pseudo Labeling : 127
# [006/3000] Train Acc: 0.717021 Loss: 0.708322 | Val Acc: 0.146713 loss: 4.284155
# Pseudo Labeling : 155
# [007/3000] Train Acc: 0.723166 Loss: 0.693179 | Val Acc: 0.140032 loss: 4.375367
# Pseudo Labeling : 84
# [008/3000] Train Acc: 0.733555 Loss: 0.678610 | Val Acc: 0.162480 loss: 4.205728
# saving model with acc 0.162
# Pseudo Labeling : 56
# [009/3000] Train Acc: 0.738650 Loss: 0.654404 | Val Acc: 0.160075 loss: 4.577152
# Pseudo Labeling : 74
# [010/3000] Train Acc: 0.744947 Loss: 0.642922 | Val Acc: 0.161411 loss: 4.407830
# Pseudo Labeling : 220
# [011/3000] Train Acc: 0.753786 Loss: 0.627348 | Val Acc: 0.156601 loss: 4.562550
# Pseudo Labeling : 151
# [012/3000] Train Acc: 0.760468 Loss: 0.617021 | Val Acc: 0.154997 loss: 4.629432
# Pseudo Labeling : 208
# [013/3000] Train Acc: 0.764927 Loss: 0.598985 | Val Acc: 0.160609 loss: 4.590823
# Pseudo Labeling : 275
# [014/3000] Train Acc: 0.760777 Loss: 0.596723 | Val Acc: 0.160075 loss: 4.614780
# Pseudo Labeling : 365
# [015/3000] Train Acc: 0.770400 Loss: 0.572305 | Val Acc: 0.163014 loss: 4.684281
# saving model with acc 0.163
# Pseudo Labeling : 291
# [016/3000] Train Acc: 0.772629 Loss: 0.572693 | Val Acc: 0.152058 loss: 4.462851
# Pseudo Labeling : 288
# [017/3000] Train Acc: 0.773240 Loss: 0.571393 | Val Acc: 0.152325 loss: 4.765745
# Pseudo Labeling : 316
# [018/3000] Train Acc: 0.773394 Loss: 0.561035 | Val Acc: 0.163282 loss: 4.732078
# saving model with acc 0.163
# Pseudo Labeling : 293
# [019/3000] Train Acc: 0.774166 Loss: 0.564585 | Val Acc: 0.159808 loss: 4.631488
# Pseudo Labeling : 360
# [020/3000] Train Acc: 0.779003 Loss: 0.549785 | Val Acc: 0.164885 loss: 4.686623
# saving model with acc 0.165
# Pseudo Labeling : 332
# [021/3000] Train Acc: 0.785724 Loss: 0.546662 | Val Acc: 0.156334 loss: 4.659639
# Pseudo Labeling : 313
# [022/3000] Train Acc: 0.784868 Loss: 0.549434 | Val Acc: 0.163549 loss: 4.687103
# Pseudo Labeling : 327
# [023/3000] Train Acc: 0.787746 Loss: 0.523918 | Val Acc: 0.162747 loss: 4.688747
# Pseudo Labeling : 333
# [024/3000] Train Acc: 0.794104 Loss: 0.521089 | Val Acc: 0.167023 loss: 4.753572
# saving model with acc 0.167
# Pseudo Labeling : 331
# [025/3000] Train Acc: 0.798915 Loss: 0.515250 | Val Acc: 0.154730 loss: 4.760958
# Pseudo Labeling : 359
# [026/3000] Train Acc: 0.793801 Loss: 0.509072 | Val Acc: 0.156334 loss: 4.685443
# Pseudo Labeling : 259
# [027/3000] Train Acc: 0.792250 Loss: 0.518167 | Val Acc: 0.165152 loss: 4.755024
# Pseudo Labeling : 257
# [028/3000] Train Acc: 0.794193 Loss: 0.507560 | Val Acc: 0.193212 loss: 4.747555
# saving model with acc 0.193
# Pseudo Labeling : 314
# [029/3000] Train Acc: 0.794437 Loss: 0.501896 | Val Acc: 0.168359 loss: 4.689167
# Pseudo Labeling : 316
# [030/3000] Train Acc: 0.802775 Loss: 0.499176 | Val Acc: 0.172902 loss: 4.589840
# Pseudo Labeling : 317
# [031/3000] Train Acc: 0.802002 Loss: 0.494280 | Val Acc: 0.167023 loss: 4.528845
# Pseudo Labeling : 403
# [032/3000] Train Acc: 0.803175 Loss: 0.493300 | Val Acc: 0.191609 loss: 4.707098
# Pseudo Labeling : 406
# [033/3000] Train Acc: 0.804515 Loss: 0.492320 | Val Acc: 0.167023 loss: 4.575680
# Pseudo Labeling : 322
# [034/3000] Train Acc: 0.799581 Loss: 0.493993 | Val Acc: 0.164618 loss: 4.792829
# Pseudo Labeling : 362
# [035/3000] Train Acc: 0.806302 Loss: 0.481993 | Val Acc: 0.165420 loss: 4.700508
# Pseudo Labeling : 402
# [036/3000] Train Acc: 0.804594 Loss: 0.483298 | Val Acc: 0.167023 loss: 4.902660
# Pseudo Labeling : 411
# [037/3000] Train Acc: 0.805229 Loss: 0.483613 | Val Acc: 0.164885 loss: 4.749533
# Pseudo Labeling : 410
# [038/3000] Train Acc: 0.805671 Loss: 0.480836 | Val Acc: 0.167023 loss: 4.592431
# Pseudo Labeling : 385
# [039/3000] Train Acc: 0.806136 Loss: 0.480223 | Val Acc: 0.169161 loss: 4.730362
# Pseudo Labeling : 402
# [040/3000] Train Acc: 0.809604 Loss: 0.477372 | Val Acc: 0.167023 loss: 4.868200
# Pseudo Labeling : 427
# [041/3000] Train Acc: 0.810433 Loss: 0.466661 | Val Acc: 0.165152 loss: 4.704408
# Pseudo Labeling : 461
# [042/3000] Train Acc: 0.817204 Loss: 0.464175 | Val Acc: 0.160877 loss: 4.985912
# Pseudo Labeling : 426
# [043/3000] Train Acc: 0.810941 Loss: 0.473803 | Val Acc: 0.169161 loss: 4.899237
# Pseudo Labeling : 448
# [044/3000] Train Acc: 0.810821 Loss: 0.463531 | Val Acc: 0.162480 loss: 4.796988
# Pseudo Labeling : 394
# [045/3000] Train Acc: 0.817643 Loss: 0.461014 | Val Acc: 0.164618 loss: 4.808997
# Pseudo Labeling : 415
# [046/3000] Train Acc: 0.817307 Loss: 0.457047 | Val Acc: 0.166489 loss: 4.557589
# Pseudo Labeling : 478
# [047/3000] Train Acc: 0.816822 Loss: 0.454039 | Val Acc: 0.167023 loss: 4.809459
# Pseudo Labeling : 460
# [048/3000] Train Acc: 0.817386 Loss: 0.453569 | Val Acc: 0.164618 loss: 4.630758
# Pseudo Labeling : 372
# [049/3000] Train Acc: 0.817968 Loss: 0.458888 | Val Acc: 0.169161 loss: 4.755748
# Pseudo Labeling : 478
# [050/3000] Train Acc: 0.817275 Loss: 0.452617 | Val Acc: 0.163014 loss: 4.764094
# Pseudo Labeling : 497
# [051/3000] Train Acc: 0.814072 Loss: 0.454957 | Val Acc: 0.159006 loss: 4.904340
# Pseudo Labeling : 375
# [052/3000] Train Acc: 0.815136 Loss: 0.459056 | Val Acc: 0.162747 loss: 4.823780
# Pseudo Labeling : 498
# [053/3000] Train Acc: 0.817124 Loss: 0.452594 | Val Acc: 0.169161 loss: 4.600891
# Pseudo Labeling : 525
# [054/3000] Train Acc: 0.820347 Loss: 0.448033 | Val Acc: 0.169161 loss: 4.955566
# Pseudo Labeling : 337
# [055/3000] Train Acc: 0.817683 Loss: 0.449831 | Val Acc: 0.158739 loss: 4.714789
# Pseudo Labeling : 414
# [056/3000] Train Acc: 0.822302 Loss: 0.447809 | Val Acc: 0.167023 loss: 4.687976
# Pseudo Labeling : 349
# [057/3000] Train Acc: 0.820437 Loss: 0.447348 | Val Acc: 0.168626 loss: 4.726279
# Pseudo Labeling : 425
# [058/3000] Train Acc: 0.822364 Loss: 0.441166 | Val Acc: 0.167023 loss: 4.771213
# Pseudo Labeling : 430
# [059/3000] Train Acc: 0.822356 Loss: 0.442840 | Val Acc: 0.171566 loss: 4.762609
# Pseudo Labeling : 387
# [060/3000] Train Acc: 0.816453 Loss: 0.448679 | Val Acc: 0.167023 loss: 4.819932
# Pseudo Labeling : 402
# [061/3000] Train Acc: 0.819560 Loss: 0.448721 | Val Acc: 0.169161 loss: 4.760883
# Pseudo Labeling : 433
# [062/3000] Train Acc: 0.824794 Loss: 0.434405 | Val Acc: 0.192945 loss: 4.813072
# Pseudo Labeling : 445
# [063/3000] Train Acc: 0.819674 Loss: 0.441351 | Val Acc: 0.167557 loss: 4.758940
# Pseudo Labeling : 455
# [064/3000] Train Acc: 0.822580 Loss: 0.438441 | Val Acc: 0.169161 loss: 4.722946
# Pseudo Labeling : 414
# [065/3000] Train Acc: 0.824707 Loss: 0.435096 | Val Acc: 0.167290 loss: 4.705649
# Pseudo Labeling : 472
# [066/3000] Train Acc: 0.825949 Loss: 0.434126 | Val Acc: 0.163014 loss: 4.742992
# Pseudo Labeling : 401
# [067/3000] Train Acc: 0.826902 Loss: 0.433507 | Val Acc: 0.165152 loss: 4.744567
# Pseudo Labeling : 403
# [068/3000] Train Acc: 0.825753 Loss: 0.436669 | Val Acc: 0.169161 loss: 4.861721
# Pseudo Labeling : 444
# [069/3000] Train Acc: 0.820831 Loss: 0.431049 | Val Acc: 0.169161 loss: 4.879510
# Pseudo Labeling : 483
# [070/3000] Train Acc: 0.827497 Loss: 0.431924 | Val Acc: 0.167023 loss: 4.905494
# Pseudo Labeling : 470
# [071/3000] Train Acc: 0.826704 Loss: 0.432286 | Val Acc: 0.177445 loss: 4.686153
# Pseudo Labeling : 361
# [072/3000] Train Acc: 0.829647 Loss: 0.422507 | Val Acc: 0.171566 loss: 4.705647
# Pseudo Labeling : 449
# [073/3000] Train Acc: 0.825365 Loss: 0.426454 | Val Acc: 0.169161 loss: 4.684120
# Pseudo Labeling : 566
# [074/3000] Train Acc: 0.825779 Loss: 0.427844 | Val Acc: 0.165152 loss: 4.721954
# Pseudo Labeling : 409
# [075/3000] Train Acc: 0.827707 Loss: 0.434119 | Val Acc: 0.169963 loss: 4.558513
# Pseudo Labeling : 531
# [076/3000] Train Acc: 0.828031 Loss: 0.424145 | Val Acc: 0.169161 loss: 4.887783
# Pseudo Labeling : 522
# [077/3000] Train Acc: 0.828512 Loss: 0.428315 | Val Acc: 0.164618 loss: 4.991437
# Pseudo Labeling : 482
# [078/3000] Train Acc: 0.829428 Loss: 0.426017 | Val Acc: 0.161144 loss: 4.756687
# Pseudo Labeling : 520
# [079/3000] Train Acc: 0.823905 Loss: 0.423259 | Val Acc: 0.177445 loss: 4.677405
# Pseudo Labeling : 548
# [080/3000] Train Acc: 0.830669 Loss: 0.424581 | Val Acc: 0.169161 loss: 4.817937
# Pseudo Labeling : 467
# [081/3000] Train Acc: 0.829716 Loss: 0.423787 | Val Acc: 0.169161 loss: 4.708742
# Pseudo Labeling : 481
# [082/3000] Train Acc: 0.827345 Loss: 0.424523 | Val Acc: 0.171566 loss: 4.649101
# Pseudo Labeling : 551
# [083/3000] Train Acc: 0.832700 Loss: 0.415370 | Val Acc: 0.163014 loss: 4.646853
# Pseudo Labeling : 462
# [084/3000] Train Acc: 0.833485 Loss: 0.413304 | Val Acc: 0.169161 loss: 4.889376
# Pseudo Labeling : 487
# [085/3000] Train Acc: 0.823982 Loss: 0.423561 | Val Acc: 0.177445 loss: 4.919895
# Pseudo Labeling : 551
# [086/3000] Train Acc: 0.831153 Loss: 0.419863 | Val Acc: 0.169428 loss: 4.922693
# Pseudo Labeling : 513
# [087/3000] Train Acc: 0.829576 Loss: 0.415299 | Val Acc: 0.171566 loss: 4.958478
# Pseudo Labeling : 523
# [088/3000] Train Acc: 0.831106 Loss: 0.420839 | Val Acc: 0.169428 loss: 4.936898
# Pseudo Labeling : 421
# [089/3000] Train Acc: 0.832261 Loss: 0.417175 | Val Acc: 0.169428 loss: 4.939542
# Pseudo Labeling : 575
# [090/3000] Train Acc: 0.827038 Loss: 0.419226 | Val Acc: 0.171566 loss: 4.638918
# Pseudo Labeling : 503
# [091/3000] Train Acc: 0.836770 Loss: 0.406605 | Val Acc: 0.171566 loss: 4.841731
# Pseudo Labeling : 529
# [092/3000] Train Acc: 0.834140 Loss: 0.415391 | Val Acc: 0.171566 loss: 4.973892
# Pseudo Labeling : 604
# [093/3000] Train Acc: 0.830764 Loss: 0.414277 | Val Acc: 0.162747 loss: 4.848127
# Pseudo Labeling : 538
# [094/3000] Train Acc: 0.833591 Loss: 0.418312 | Val Acc: 0.169161 loss: 4.761632
# Pseudo Labeling : 579
# [095/3000] Train Acc: 0.829784 Loss: 0.416011 | Val Acc: 0.169161 loss: 4.951591
# Pseudo Labeling : 470
# [096/3000] Train Acc: 0.832470 Loss: 0.418121 | Val Acc: 0.171566 loss: 4.865719
# Pseudo Labeling : 514
# [097/3000] Train Acc: 0.828036 Loss: 0.419241 | Val Acc: 0.164083 loss: 4.853710
# Pseudo Labeling : 598
# [098/3000] Train Acc: 0.836931 Loss: 0.405236 | Val Acc: 0.169161 loss: 4.886877
# Pseudo Labeling : 547
# [099/3000] Train Acc: 0.850512 Loss: 0.372525 | Val Acc: 0.171566 loss: 4.844198
# Pseudo Labeling : 483
# [100/3000] Train Acc: 0.852159 Loss: 0.366868 | Val Acc: 0.171566 loss: 4.874607
# Pseudo Labeling : 543
# [101/3000] Train Acc: 0.855697 Loss: 0.357509 | Val Acc: 0.199893 loss: 4.830966
# saving model with acc 0.200
# Pseudo Labeling : 534
# [102/3000] Train Acc: 0.855419 Loss: 0.353426 | Val Acc: 0.171566 loss: 4.781724
# Pseudo Labeling : 516
# [103/3000] Train Acc: 0.854218 Loss: 0.352876 | Val Acc: 0.171566 loss: 4.894892
# Pseudo Labeling : 555
# [104/3000] Train Acc: 0.857548 Loss: 0.353523 | Val Acc: 0.171566 loss: 4.910903
# Pseudo Labeling : 551
# [105/3000] Train Acc: 0.857124 Loss: 0.348455 | Val Acc: 0.171566 loss: 4.868650
# Pseudo Labeling : 554
# [106/3000] Train Acc: 0.855026 Loss: 0.354114 | Val Acc: 0.171566 loss: 4.919124
# Pseudo Labeling : 539
# [107/3000] Train Acc: 0.855659 Loss: 0.350996 | Val Acc: 0.171566 loss: 4.952157
# Pseudo Labeling : 544
# [108/3000] Train Acc: 0.857060 Loss: 0.350920 | Val Acc: 0.171566 loss: 4.888609
# Pseudo Labeling : 521
# [109/3000] Train Acc: 0.856137 Loss: 0.347903 | Val Acc: 0.171566 loss: 4.910327
# Pseudo Labeling : 568
# [110/3000] Train Acc: 0.857088 Loss: 0.347594 | Val Acc: 0.171566 loss: 4.930715
# Pseudo Labeling : 552
# [111/3000] Train Acc: 0.860549 Loss: 0.346292 | Val Acc: 0.171566 loss: 5.053553
# Pseudo Labeling : 496
# [112/3000] Train Acc: 0.855646 Loss: 0.350392 | Val Acc: 0.171566 loss: 4.888855
# Pseudo Labeling : 535
# [113/3000] Train Acc: 0.857493 Loss: 0.346679 | Val Acc: 0.171566 loss: 5.004231
# Pseudo Labeling : 542
# [114/3000] Train Acc: 0.858202 Loss: 0.348684 | Val Acc: 0.171566 loss: 4.969115
# Pseudo Labeling : 596
# [115/3000] Train Acc: 0.862164 Loss: 0.346215 | Val Acc: 0.171566 loss: 5.005564
# Pseudo Labeling : 579
# [116/3000] Train Acc: 0.857510 Loss: 0.344528 | Val Acc: 0.171566 loss: 4.932907
# Pseudo Labeling : 560
# [117/3000] Train Acc: 0.856950 Loss: 0.346335 | Val Acc: 0.171566 loss: 4.885398
# Pseudo Labeling : 579
# [118/3000] Train Acc: 0.859183 Loss: 0.342348 | Val Acc: 0.171566 loss: 5.039032
# Pseudo Labeling : 573
# [119/3000] Train Acc: 0.860544 Loss: 0.338874 | Val Acc: 0.171566 loss: 4.921067
# Pseudo Labeling : 601
# [120/3000] Train Acc: 0.862273 Loss: 0.343468 | Val Acc: 0.171566 loss: 4.960630
# Pseudo Labeling : 611
# [121/3000] Train Acc: 0.859857 Loss: 0.337991 | Val Acc: 0.171566 loss: 4.992657
# Pseudo Labeling : 605
# [122/3000] Train Acc: 0.858969 Loss: 0.343736 | Val Acc: 0.171566 loss: 5.079670
# Pseudo Labeling : 640
# [123/3000] Train Acc: 0.863770 Loss: 0.336880 | Val Acc: 0.171566 loss: 4.990838
# Pseudo Labeling : 616
# [124/3000] Train Acc: 0.860544 Loss: 0.338516 | Val Acc: 0.171566 loss: 4.951784
# Pseudo Labeling : 566
# [125/3000] Train Acc: 0.859258 Loss: 0.341232 | Val Acc: 0.171566 loss: 4.948614
# Pseudo Labeling : 585
# [126/3000] Train Acc: 0.859044 Loss: 0.336593 | Val Acc: 0.171566 loss: 5.031258
# Pseudo Labeling : 562
# [127/3000] Train Acc: 0.859480 Loss: 0.336829 | Val Acc: 0.171566 loss: 4.978708
# Pseudo Labeling : 596
# [128/3000] Train Acc: 0.861586 Loss: 0.342125 | Val Acc: 0.171566 loss: 4.914365
# Pseudo Labeling : 644
# [129/3000] Train Acc: 0.860346 Loss: 0.339687 | Val Acc: 0.171566 loss: 4.839763
# Pseudo Labeling : 596
# [130/3000] Train Acc: 0.861843 Loss: 0.337788 | Val Acc: 0.171566 loss: 4.987818
# Pseudo Labeling : 574
# [131/3000] Train Acc: 0.858559 Loss: 0.339399 | Val Acc: 0.171566 loss: 4.911716
# Pseudo Labeling : 602
# [132/3000] Train Acc: 0.861061 Loss: 0.340383 | Val Acc: 0.171566 loss: 4.873662
# Pseudo Labeling : 564
# [133/3000] Train Acc: 0.861687 Loss: 0.335447 | Val Acc: 0.171566 loss: 4.946190
# Pseudo Labeling : 574
# [134/3000] Train Acc: 0.862420 Loss: 0.335489 | Val Acc: 0.171566 loss: 4.899794
# Pseudo Labeling : 652
# [135/3000] Train Acc: 0.863747 Loss: 0.336868 | Val Acc: 0.171566 loss: 4.946116
# Pseudo Labeling : 606
# [136/3000] Train Acc: 0.861611 Loss: 0.337298 | Val Acc: 0.171566 loss: 5.006227
# Pseudo Labeling : 629
# [137/3000] Train Acc: 0.862712 Loss: 0.333047 | Val Acc: 0.171566 loss: 4.929836
# Pseudo Labeling : 658
# [138/3000] Train Acc: 0.862775 Loss: 0.333087 | Val Acc: 0.171566 loss: 4.991057
# Pseudo Labeling : 623
# [139/3000] Train Acc: 0.861697 Loss: 0.335813 | Val Acc: 0.171566 loss: 5.014735
# Pseudo Labeling : 624
# [140/3000] Train Acc: 0.856895 Loss: 0.339664 | Val Acc: 0.171566 loss: 4.982650
# Pseudo Labeling : 633
# [141/3000] Train Acc: 0.865953 Loss: 0.331768 | Val Acc: 0.171566 loss: 4.971903
# Pseudo Labeling : 615
# [142/3000] Train Acc: 0.862268 Loss: 0.335713 | Val Acc: 0.171566 loss: 4.900962
# Pseudo Labeling : 653
# [143/3000] Train Acc: 0.861387 Loss: 0.335946 | Val Acc: 0.171566 loss: 4.884261
# Pseudo Labeling : 619
# [144/3000] Train Acc: 0.864742 Loss: 0.330903 | Val Acc: 0.171566 loss: 5.096306
# Pseudo Labeling : 602
# [145/3000] Train Acc: 0.859263 Loss: 0.338524 | Val Acc: 0.171566 loss: 4.987969
# Pseudo Labeling : 637
# [146/3000] Train Acc: 0.862078 Loss: 0.334268 | Val Acc: 0.171566 loss: 4.998984
# Pseudo Labeling : 652
# [147/3000] Train Acc: 0.864964 Loss: 0.330134 | Val Acc: 0.171566 loss: 4.960235
# Pseudo Labeling : 600
# [148/3000] Train Acc: 0.862457 Loss: 0.332948 | Val Acc: 0.171566 loss: 4.915697
# Pseudo Labeling : 633
# [149/3000] Train Acc: 0.862042 Loss: 0.333505 | Val Acc: 0.171566 loss: 5.102823
# Pseudo Labeling : 629
# [150/3000] Train Acc: 0.862905 Loss: 0.329022 | Val Acc: 0.171566 loss: 5.032858
# Pseudo Labeling : 631
# [151/3000] Train Acc: 0.863692 Loss: 0.331001 | Val Acc: 0.171566 loss: 5.045261
# Pseudo Labeling : 647
# [152/3000] Train Acc: 0.858067 Loss: 0.336154 | Val Acc: 0.171566 loss: 4.987183
# Pseudo Labeling : 662
# [153/3000] Train Acc: 0.862170 Loss: 0.334014 | Val Acc: 0.171566 loss: 5.168800
# Pseudo Labeling : 642
# [154/3000] Train Acc: 0.859815 Loss: 0.332065 | Val Acc: 0.171566 loss: 5.082815
# Pseudo Labeling : 648
# [155/3000] Train Acc: 0.861791 Loss: 0.332737 | Val Acc: 0.171566 loss: 4.981901
# Pseudo Labeling : 661
# [156/3000] Train Acc: 0.866641 Loss: 0.329533 | Val Acc: 0.171566 loss: 4.992184
# Pseudo Labeling : 684
# [157/3000] Train Acc: 0.861278 Loss: 0.330684 | Val Acc: 0.171566 loss: 5.028418
# Pseudo Labeling : 629
# [158/3000] Train Acc: 0.863225 Loss: 0.330661 | Val Acc: 0.171566 loss: 5.024598
# Pseudo Labeling : 654
# [159/3000] Train Acc: 0.863124 Loss: 0.332740 | Val Acc: 0.171566 loss: 5.119257
# Pseudo Labeling : 635
# [160/3000] Train Acc: 0.861868 Loss: 0.327399 | Val Acc: 0.171566 loss: 5.122335
# Pseudo Labeling : 607
# [161/3000] Train Acc: 0.861491 Loss: 0.332938 | Val Acc: 0.171566 loss: 5.126463
# Pseudo Labeling : 625
# [162/3000] Train Acc: 0.865563 Loss: 0.329793 | Val Acc: 0.171566 loss: 5.011593
# Pseudo Labeling : 656
# [163/3000] Train Acc: 0.864742 Loss: 0.330963 | Val Acc: 0.171566 loss: 5.023255
# Pseudo Labeling : 609
# [164/3000] Train Acc: 0.864013 Loss: 0.328137 | Val Acc: 0.171566 loss: 5.086372
# Pseudo Labeling : 626
# [165/3000] Train Acc: 0.863135 Loss: 0.330700 | Val Acc: 0.171566 loss: 5.077966
# Pseudo Labeling : 679
# [166/3000] Train Acc: 0.865069 Loss: 0.328423 | Val Acc: 0.171566 loss: 5.015649
# Pseudo Labeling : 647
# [167/3000] Train Acc: 0.863767 Loss: 0.324588 | Val Acc: 0.171566 loss: 5.042702
# Pseudo Labeling : 671
# [168/3000] Train Acc: 0.866598 Loss: 0.329220 | Val Acc: 0.171566 loss: 4.854488
# Pseudo Labeling : 631
# [169/3000] Train Acc: 0.865359 Loss: 0.326721 | Val Acc: 0.171566 loss: 5.067960
# Pseudo Labeling : 672
# [170/3000] Train Acc: 0.865712 Loss: 0.324884 | Val Acc: 0.171566 loss: 5.074566
# Pseudo Labeling : 670
# [171/3000] Train Acc: 0.861985 Loss: 0.333507 | Val Acc: 0.171566 loss: 5.060328
# Pseudo Labeling : 670
# [172/3000] Train Acc: 0.863776 Loss: 0.330767 | Val Acc: 0.171566 loss: 4.862632
# Pseudo Labeling : 690
# [173/3000] Train Acc: 0.864589 Loss: 0.324152 | Val Acc: 0.171566 loss: 4.982970
# Pseudo Labeling : 660
# [174/3000] Train Acc: 0.862985 Loss: 0.329547 | Val Acc: 0.171566 loss: 5.039164
# Pseudo Labeling : 637
# [175/3000] Train Acc: 0.861245 Loss: 0.331481 | Val Acc: 0.171566 loss: 4.856772
# Pseudo Labeling : 701
# [176/3000] Train Acc: 0.862322 Loss: 0.328284 | Val Acc: 0.171566 loss: 5.130336
# Pseudo Labeling : 643
# [177/3000] Train Acc: 0.863797 Loss: 0.327222 | Val Acc: 0.171566 loss: 4.889812
# Pseudo Labeling : 674
# [178/3000] Train Acc: 0.862148 Loss: 0.333972 | Val Acc: 0.171566 loss: 5.025185
# Pseudo Labeling : 634
# [179/3000] Train Acc: 0.864936 Loss: 0.327830 | Val Acc: 0.171566 loss: 5.034020
# Pseudo Labeling : 677
# [180/3000] Train Acc: 0.863325 Loss: 0.329266 | Val Acc: 0.171566 loss: 5.037991
# Pseudo Labeling : 652
# [181/3000] Train Acc: 0.867461 Loss: 0.323984 | Val Acc: 0.171566 loss: 4.914415
# Pseudo Labeling : 689
# [182/3000] Train Acc: 0.865347 Loss: 0.325605 | Val Acc: 0.171566 loss: 5.079367
# Pseudo Labeling : 643
# [183/3000] Train Acc: 0.865014 Loss: 0.323073 | Val Acc: 0.171566 loss: 5.061757
# Pseudo Labeling : 672
# [184/3000] Train Acc: 0.864880 Loss: 0.326635 | Val Acc: 0.171566 loss: 4.955981
# Pseudo Labeling : 675
# [185/3000] Train Acc: 0.860751 Loss: 0.329084 | Val Acc: 0.171566 loss: 4.832110
# Pseudo Labeling : 700
# [186/3000] Train Acc: 0.860271 Loss: 0.328753 | Val Acc: 0.171566 loss: 5.090463
# Pseudo Labeling : 673
# [187/3000] Train Acc: 0.866616 Loss: 0.324289 | Val Acc: 0.171566 loss: 5.178956
# Pseudo Labeling : 621
# [188/3000] Train Acc: 0.864823 Loss: 0.328754 | Val Acc: 0.171566 loss: 5.122066
# Pseudo Labeling : 672
# [189/3000] Train Acc: 0.867055 Loss: 0.323517 | Val Acc: 0.171566 loss: 5.056299
# Pseudo Labeling : 673
# [190/3000] Train Acc: 0.866424 Loss: 0.324251 | Val Acc: 0.171566 loss: 5.209010
# Pseudo Labeling : 658
# [191/3000] Train Acc: 0.868216 Loss: 0.322791 | Val Acc: 0.171566 loss: 5.143375
# Pseudo Labeling : 707
# [192/3000] Train Acc: 0.863204 Loss: 0.326488 | Val Acc: 0.171566 loss: 5.161674
# Pseudo Labeling : 664
# [193/3000] Train Acc: 0.864683 Loss: 0.324279 | Val Acc: 0.171566 loss: 5.187056
# Pseudo Labeling : 647
# [194/3000] Train Acc: 0.861526 Loss: 0.326811 | Val Acc: 0.171566 loss: 5.085334
# Pseudo Labeling : 682
# [195/3000] Train Acc: 0.863944 Loss: 0.324263 | Val Acc: 0.171566 loss: 5.099580
# Pseudo Labeling : 636
# [196/3000] Train Acc: 0.866363 Loss: 0.323366 | Val Acc: 0.171566 loss: 5.007260
# Pseudo Labeling : 699
# [197/3000] Train Acc: 0.867539 Loss: 0.320674 | Val Acc: 0.171566 loss: 5.045919
# Pseudo Labeling : 689
# [198/3000] Train Acc: 0.867391 Loss: 0.318650 | Val Acc: 0.171566 loss: 5.083642
# Pseudo Labeling : 650
# [199/3000] Train Acc: 0.869685 Loss: 0.321723 | Val Acc: 0.171566 loss: 5.301567
# Pseudo Labeling : 583
# [200/3000] Train Acc: 0.864622 Loss: 0.321397 | Val Acc: 0.171566 loss: 5.058284
# Pseudo Labeling : 675
# [201/3000] Train Acc: 0.867783 Loss: 0.321360 | Val Acc: 0.171566 loss: 5.118775
# Pseudo Labeling : 669
# [202/3000] Train Acc: 0.868564 Loss: 0.317228 | Val Acc: 0.171566 loss: 5.019284
# Pseudo Labeling : 679
# [203/3000] Train Acc: 0.865516 Loss: 0.323917 | Val Acc: 0.171566 loss: 5.020603
# Pseudo Labeling : 682
# [204/3000] Train Acc: 0.865350 Loss: 0.317364 | Val Acc: 0.171566 loss: 5.158657
# Pseudo Labeling : 654
# [205/3000] Train Acc: 0.871831 Loss: 0.316186 | Val Acc: 0.171566 loss: 5.272652
# Pseudo Labeling : 697
# [206/3000] Train Acc: 0.867969 Loss: 0.316940 | Val Acc: 0.171566 loss: 5.045166
# Pseudo Labeling : 688
# [207/3000] Train Acc: 0.866424 Loss: 0.318101 | Val Acc: 0.171566 loss: 5.135999
# Pseudo Labeling : 693
# [208/3000] Train Acc: 0.867105 Loss: 0.319873 | Val Acc: 0.171566 loss: 4.993796
# Pseudo Labeling : 670
# [209/3000] Train Acc: 0.868764 Loss: 0.314541 | Val Acc: 0.171566 loss: 5.024426
# Pseudo Labeling : 675
# [210/3000] Train Acc: 0.868295 Loss: 0.319257 | Val Acc: 0.171566 loss: 5.073158
# Pseudo Labeling : 697
# [211/3000] Train Acc: 0.868161 Loss: 0.316171 | Val Acc: 0.171566 loss: 5.079695
# Pseudo Labeling : 682
# [212/3000] Train Acc: 0.870527 Loss: 0.311964 | Val Acc: 0.171566 loss: 5.125991
# Pseudo Labeling : 658
# [213/3000] Train Acc: 0.869624 Loss: 0.316951 | Val Acc: 0.171566 loss: 5.088175
# Pseudo Labeling : 675
# [214/3000] Train Acc: 0.868998 Loss: 0.319415 | Val Acc: 0.171566 loss: 5.020128
# Pseudo Labeling : 670
# [215/3000] Train Acc: 0.868956 Loss: 0.319456 | Val Acc: 0.171566 loss: 5.083826
# Pseudo Labeling : 694
# [216/3000] Train Acc: 0.870051 Loss: 0.317630 | Val Acc: 0.171566 loss: 5.124561
# Pseudo Labeling : 684
# [217/3000] Train Acc: 0.870096 Loss: 0.320151 | Val Acc: 0.171566 loss: 5.066674
# Pseudo Labeling : 701
# [218/3000] Train Acc: 0.869471 Loss: 0.315281 | Val Acc: 0.171566 loss: 5.126973
# Pseudo Labeling : 691
# [219/3000] Train Acc: 0.868110 Loss: 0.315873 | Val Acc: 0.171566 loss: 5.034767
# Pseudo Labeling : 697
# [220/3000] Train Acc: 0.865288 Loss: 0.321008 | Val Acc: 0.171566 loss: 5.139625
# Pseudo Labeling : 669
# [221/3000] Train Acc: 0.866901 Loss: 0.320729 | Val Acc: 0.171566 loss: 5.088430
# Pseudo Labeling : 637
# [222/3000] Train Acc: 0.865218 Loss: 0.319144 | Val Acc: 0.171566 loss: 5.062667
# Pseudo Labeling : 696
# [223/3000] Train Acc: 0.867514 Loss: 0.315545 | Val Acc: 0.171566 loss: 5.109059
# Pseudo Labeling : 650
# [224/3000] Train Acc: 0.867828 Loss: 0.321787 | Val Acc: 0.171566 loss: 5.024879
# Pseudo Labeling : 697
# [225/3000] Train Acc: 0.868416 Loss: 0.313565 | Val Acc: 0.171566 loss: 5.138327
# Pseudo Labeling : 691
# [226/3000] Train Acc: 0.867663 Loss: 0.319698 | Val Acc: 0.171566 loss: 5.106818
# Pseudo Labeling : 670
# [227/3000] Train Acc: 0.869980 Loss: 0.317053 | Val Acc: 0.171566 loss: 5.235888
# Pseudo Labeling : 659
# [228/3000] Train Acc: 0.869632 Loss: 0.319019 | Val Acc: 0.171566 loss: 5.035897
# Pseudo Labeling : 669
# [229/3000] Train Acc: 0.868244 Loss: 0.320295 | Val Acc: 0.171566 loss: 5.029056
# Pseudo Labeling : 687
# [230/3000] Train Acc: 0.865649 Loss: 0.320107 | Val Acc: 0.171566 loss: 5.053390
# Pseudo Labeling : 671
# [231/3000] Train Acc: 0.868005 Loss: 0.318312 | Val Acc: 0.171566 loss: 5.110103
# Pseudo Labeling : 664
# [232/3000] Train Acc: 0.868842 Loss: 0.316723 | Val Acc: 0.171566 loss: 5.020255
# Pseudo Labeling : 733
# [233/3000] Train Acc: 0.867253 Loss: 0.317694 | Val Acc: 0.171566 loss: 5.020500
# Pseudo Labeling : 681
# [234/3000] Train Acc: 0.867067 Loss: 0.321706 | Val Acc: 0.171566 loss: 5.016329
# Pseudo Labeling : 671
# [235/3000] Train Acc: 0.866662 Loss: 0.321389 | Val Acc: 0.171566 loss: 4.970596
# Pseudo Labeling : 711
# [236/3000] Train Acc: 0.865535 Loss: 0.317907 | Val Acc: 0.171566 loss: 5.116002
# Pseudo Labeling : 683
# [237/3000] Train Acc: 0.868490 Loss: 0.316849 | Val Acc: 0.171566 loss: 5.107828
# Pseudo Labeling : 679
# [238/3000] Train Acc: 0.870374 Loss: 0.315793 | Val Acc: 0.171566 loss: 5.107667
# Pseudo Labeling : 676
# [239/3000] Train Acc: 0.869582 Loss: 0.315744 | Val Acc: 0.171566 loss: 5.088510
# Pseudo Labeling : 673
# [240/3000] Train Acc: 0.867255 Loss: 0.316879 | Val Acc: 0.171566 loss: 5.013154
# Pseudo Labeling : 727
# [241/3000] Train Acc: 0.869177 Loss: 0.320281 | Val Acc: 0.171566 loss: 5.041787
# Pseudo Labeling : 691
# [242/3000] Train Acc: 0.866066 Loss: 0.321968 | Val Acc: 0.171566 loss: 4.976938
# Pseudo Labeling : 687
# [243/3000] Train Acc: 0.868076 Loss: 0.316106 | Val Acc: 0.171566 loss: 4.973266
# Pseudo Labeling : 663
# [244/3000] Train Acc: 0.871073 Loss: 0.312471 | Val Acc: 0.171566 loss: 5.174783
# Pseudo Labeling : 674
# [245/3000] Train Acc: 0.869182 Loss: 0.314412 | Val Acc: 0.171566 loss: 5.027392
# Pseudo Labeling : 680
# [246/3000] Train Acc: 0.868145 Loss: 0.318802 | Val Acc: 0.171566 loss: 5.117047
# Pseudo Labeling : 667
# [247/3000] Train Acc: 0.868291 Loss: 0.318893 | Val Acc: 0.171566 loss: 5.053158
# Pseudo Labeling : 700
# [248/3000] Train Acc: 0.868888 Loss: 0.315222 | Val Acc: 0.171566 loss: 4.931156
# Pseudo Labeling : 683
# [249/3000] Train Acc: 0.867404 Loss: 0.318928 | Val Acc: 0.171566 loss: 5.097172
# Pseudo Labeling : 680
# [250/3000] Train Acc: 0.867570 Loss: 0.317659 | Val Acc: 0.199893 loss: 5.106183
# Pseudo Labeling : 658
# [251/3000] Train Acc: 0.868856 Loss: 0.320297 | Val Acc: 0.171566 loss: 5.035242
# Pseudo Labeling : 672
# [252/3000] Train Acc: 0.872042 Loss: 0.315436 | Val Acc: 0.171566 loss: 4.959452
# Pseudo Labeling : 676
# [253/3000] Train Acc: 0.867280 Loss: 0.320857 | Val Acc: 0.171566 loss: 5.175464
# Pseudo Labeling : 680
# [254/3000] Train Acc: 0.869679 Loss: 0.315252 | Val Acc: 0.171566 loss: 5.000740
# Pseudo Labeling : 708
# [255/3000] Train Acc: 0.865446 Loss: 0.316425 | Val Acc: 0.171566 loss: 5.010345
# Pseudo Labeling : 700
# [256/3000] Train Acc: 0.865760 Loss: 0.321425 | Val Acc: 0.171566 loss: 5.102227
# Pseudo Labeling : 690
# [257/3000] Train Acc: 0.865930 Loss: 0.317457 | Val Acc: 0.171566 loss: 5.060978
# Pseudo Labeling : 713
# [258/3000] Train Acc: 0.867594 Loss: 0.316326 | Val Acc: 0.199893 loss: 5.068007
# Pseudo Labeling : 669
# [259/3000] Train Acc: 0.866773 Loss: 0.320027 | Val Acc: 0.171566 loss: 5.145673
# Pseudo Labeling : 665
# [260/3000] Train Acc: 0.870770 Loss: 0.315334 | Val Acc: 0.171566 loss: 5.042401
# Pseudo Labeling : 696
# [261/3000] Train Acc: 0.872430 Loss: 0.311391 | Val Acc: 0.171566 loss: 5.052801
# Pseudo Labeling : 679
# [262/3000] Train Acc: 0.867370 Loss: 0.318557 | Val Acc: 0.171566 loss: 5.178844
# Pseudo Labeling : 665
# [263/3000] Train Acc: 0.870322 Loss: 0.316715 | Val Acc: 0.171566 loss: 5.124323
# Pseudo Labeling : 644
# [264/3000] Train Acc: 0.866944 Loss: 0.314039 | Val Acc: 0.171566 loss: 5.079638
# Pseudo Labeling : 708
# [265/3000] Train Acc: 0.866722 Loss: 0.315642 | Val Acc: 0.171566 loss: 5.118671
# Pseudo Labeling : 661
# [266/3000] Train Acc: 0.867537 Loss: 0.317229 | Val Acc: 0.171566 loss: 4.997021
# Pseudo Labeling : 683
# [267/3000] Train Acc: 0.866701 Loss: 0.316475 | Val Acc: 0.171566 loss: 5.222275
# Pseudo Labeling : 668
# [268/3000] Train Acc: 0.871434 Loss: 0.313228 | Val Acc: 0.171566 loss: 5.141769
# Pseudo Labeling : 647
# [269/3000] Train Acc: 0.866457 Loss: 0.320585 | Val Acc: 0.171566 loss: 5.131029
# Pseudo Labeling : 654
# [270/3000] Train Acc: 0.870807 Loss: 0.316816 | Val Acc: 0.171566 loss: 5.084088
# Pseudo Labeling : 704
# [271/3000] Train Acc: 0.865858 Loss: 0.316647 | Val Acc: 0.171566 loss: 5.199364
# Pseudo Labeling : 665
# [272/3000] Train Acc: 0.869938 Loss: 0.316276 | Val Acc: 0.199893 loss: 5.093015
# Pseudo Labeling : 684
# [273/3000] Train Acc: 0.867987 Loss: 0.315774 | Val Acc: 0.171566 loss: 5.103598
# Pseudo Labeling : 668
# [274/3000] Train Acc: 0.867980 Loss: 0.316387 | Val Acc: 0.171566 loss: 5.149762
# Pseudo Labeling : 662
# [275/3000] Train Acc: 0.869913 Loss: 0.312747 | Val Acc: 0.171566 loss: 5.024686
# Pseudo Labeling : 718
# [276/3000] Train Acc: 0.869740 Loss: 0.318333 | Val Acc: 0.171566 loss: 5.126563
# Pseudo Labeling : 702
# [277/3000] Train Acc: 0.864629 Loss: 0.320815 | Val Acc: 0.171566 loss: 5.143343
# Pseudo Labeling : 681
# [278/3000] Train Acc: 0.868857 Loss: 0.315680 | Val Acc: 0.177712 loss: 5.003068
# Pseudo Labeling : 677
# [279/3000] Train Acc: 0.869590 Loss: 0.316400 | Val Acc: 0.171566 loss: 5.187307
# Pseudo Labeling : 672
# [280/3000] Train Acc: 0.868142 Loss: 0.320354 | Val Acc: 0.171566 loss: 5.123589
# Pseudo Labeling : 694
# [281/3000] Train Acc: 0.865773 Loss: 0.312213 | Val Acc: 0.171566 loss: 5.101989
# Pseudo Labeling : 673
# [282/3000] Train Acc: 0.866935 Loss: 0.316980 | Val Acc: 0.171566 loss: 5.061438
# Pseudo Labeling : 655
# [283/3000] Train Acc: 0.871199 Loss: 0.312284 | Val Acc: 0.171566 loss: 4.986277
# Pseudo Labeling : 712
# [284/3000] Train Acc: 0.865034 Loss: 0.316003 | Val Acc: 0.171566 loss: 5.150843
# Pseudo Labeling : 670
# [285/3000] Train Acc: 0.870747 Loss: 0.315040 | Val Acc: 0.171566 loss: 5.111951
# Pseudo Labeling : 691
# [286/3000] Train Acc: 0.866386 Loss: 0.318632 | Val Acc: 0.171566 loss: 5.093950
# Pseudo Labeling : 647
# [287/3000] Train Acc: 0.868571 Loss: 0.317268 | Val Acc: 0.171566 loss: 5.132669
# Pseudo Labeling : 724
# [288/3000] Train Acc: 0.871256 Loss: 0.310615 | Val Acc: 0.171566 loss: 5.110104
# Pseudo Labeling : 672
# [289/3000] Train Acc: 0.870060 Loss: 0.313504 | Val Acc: 0.171566 loss: 5.100170
# Pseudo Labeling : 675
# [290/3000] Train Acc: 0.868487 Loss: 0.313598 | Val Acc: 0.171566 loss: 5.112105
# Pseudo Labeling : 668
# [291/3000] Train Acc: 0.870347 Loss: 0.311604 | Val Acc: 0.171566 loss: 5.144455
# Pseudo Labeling : 688
# [292/3000] Train Acc: 0.868660 Loss: 0.314407 | Val Acc: 0.171566 loss: 5.105122
# Pseudo Labeling : 719
# [293/3000] Train Acc: 0.869302 Loss: 0.316557 | Val Acc: 0.171566 loss: 5.092183
# Pseudo Labeling : 693
# [294/3000] Train Acc: 0.869149 Loss: 0.315101 | Val Acc: 0.171566 loss: 5.254400
# Pseudo Labeling : 629
# [295/3000] Train Acc: 0.869189 Loss: 0.315755 | Val Acc: 0.171566 loss: 5.125138
# Pseudo Labeling : 703
# [296/3000] Train Acc: 0.867573 Loss: 0.316959 | Val Acc: 0.171566 loss: 5.151046
# Pseudo Labeling : 679
# [297/3000] Train Acc: 0.866539 Loss: 0.318470 | Val Acc: 0.171566 loss: 5.180864
# Pseudo Labeling : 666
# [298/3000] Train Acc: 0.869754 Loss: 0.316781 | Val Acc: 0.171566 loss: 5.079636
# Pseudo Labeling : 694
# [299/3000] Train Acc: 0.869923 Loss: 0.314885 | Val Acc: 0.171566 loss: 5.140037
# Pseudo Labeling : 668
# [300/3000] Train Acc: 0.871306 Loss: 0.315432 | Val Acc: 0.171566 loss: 4.998219
# Pseudo Labeling : 685
# [301/3000] Train Acc: 0.868507 Loss: 0.314827 | Val Acc: 0.171566 loss: 5.011409
# Pseudo Labeling : 692
# [302/3000] Train Acc: 0.866394 Loss: 0.317882 | Val Acc: 0.171566 loss: 5.229076

# %%
print(f'Training use {round(end_time - start_time, 3)}s')
# Out:
# Training use 255.551s

# %%
def plot_learning_curve(train_record, valid_record, title=''):
    total_steps = len(train_record)
    x = range(total_steps)
    plt.figure(figsize=(6, 4))
    plt.plot(x, train_record, c='tab:red', label='train')
    plt.plot(x, valid_record, c='tab:cyan', label='valid')
    plt.ylim(0.0, max(valid_record) + 1)
    plt.xlabel('Training epoch')
    plt.ylabel(title)
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()

# %%
plot_learning_curve(train_acc_list, val_acc_list, 'Acc')

# %%
plot_learning_curve(train_loss_list, val_loss_list, 'Loss')

# %%
model = Classifier().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))

model.eval() # set the model to evaluation mode
train_predict = []
err = 0
for i, data in enumerate(train_loader):
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)
    outputs = model(inputs)
    _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

    for y in test_pred.cpu().numpy():
        train_predict.append(y)

Ein = np.mean(np.array(train_predict) != train_y)
F1in = metrics.f1_score(train_y, train_predict, average='macro')  
print(f'Ein = {round(Ein, 5)}')
print(f'F1_in = {round(F1in, 5)}')

val_predict = []
for i, data in enumerate(val_loader):
    inputs = data[0]
    inputs = inputs.to(device)
    outputs = model(inputs)
    _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

    for y in test_pred.cpu().numpy():
        val_predict.append(y)

Eval = np.mean(np.array(val_predict) != val_y)
F1val = metrics.f1_score(val_y, val_predict, average='macro')  
print(f'Eval = {round(Eval, 5)}')
print(f'F1_val = {round(F1val, 5)}')
# Out:
# Ein = 0.79928
# F1_in = 0.16824
# Eval = 0.80011
# F1_val = 0.10489

# %% [markdown]
# # **Deep Neural Network Test**

# %%
# create testing dataset
test_set = IBMDataset(X_test_std, None)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# create model and load weights from checkpoint
model = Classifier().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
predict = []
model.eval() # set the model to evaluation mode
for i, data in enumerate(test_loader):
    inputs = data
    inputs = inputs.to(device)
    outputs = model(inputs)
    _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

    for y in test_pred.cpu().numpy():
        predict.append(y)

print(encoder_map)
print(np.bincount(predict))
# Out:
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}
# [  36  188   36 1111   18   20]

# %%
dnn_submit_result = './dnn_result.csv'

new_encoder_map = {'No Churn':0, 'Competitor': 1, 'Dissatisfaction':2, 'Attitude': 3, 'Price':4, 'Other':5}

with open(dnn_submit_result, 'w') as f:
    f.write('Customer ID,Churn Category\n')
    for i in range(len(df_test.values)):
        id = str(df_test.values[i]).replace('[\'', '')
        id = id.replace('\']', '')
        pred = new_encoder_map.get(list(encoder_map.keys())[list(encoder_map.values()).index(predict[i])])
        f.write(f'{id},{pred}\n')

# %%
from google.colab import files

files.download(dnn_submit_result)
files.download(model_path)

# %% [markdown]
# # **XGBoost Train**

# %%
train_x, train_y, val_x, val_y = X_train[:percent], y_train[:percent], X_train[percent:], y_train[percent:]

ss = StandardScaler().fit(train_x)
train_x = ss.transform(train_x)
miss_x = ss.transform(X_train_miss)
val_x = ss.transform(val_x)
X_test_std = ss.transform(X_test)

# %%
classifier = XGBClassifier(
    learning_rate =0.3,
    n_estimators=20,
    max_depth=10,
    min_child_weight=1,
    gamma=0,
    subsample=0.5,
    colsample_bytree=0.8,
    scale_pos_weight=1,
    use_label_encoder =False,
    eval_metric='mlogloss')

# %%
start_time = time.time()
model = classifier.fit(train_x, train_y)
end_time = time.time()

train_predict = model.predict(train_x)
val_predict = model.predict(val_x)

# %%
print(f'Training use {round(end_time - start_time, 3)}s')
# Out:
# Training use 3.247s

# %%
Ein = np.mean(np.array(train_predict) != train_y)
F1in = metrics.f1_score(train_y, train_predict, average='macro')  
print(f'Ein = {round(Ein, 5)}')
print(f'F1_in = {round(F1in, 5)}')
print('XGBoost Train Score {}'.format(model.score(train_x, train_y)))
print()

Eval = np.mean(np.array(val_predict) != val_y)
F1val = metrics.f1_score(val_y, val_predict, average='macro')  
print(f'Eval = {round(Eval, 5)}')
print(f'F1_val = {round(F1val, 5)}')
print('XGBoost Valid Score {}'.format(model.score(val_x, val_y)))
# Out:
# Ein = 0.10584
# F1_in = 0.87069
# XGBoost Train Score 0.8941600962180943
#
# Eval = 0.82843
# F1_val = 0.14097
# XGBoost Valid Score 0.17156600748262962

# %% [markdown]
# # **XGBoost Test**

# %%
predict = model.predict(X_test_std)
predict = np.array(predict, dtype=np.int64)

print(encoder_map)
print(np.bincount(predict))
# Out:
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}
# [  40  198   34 1113   10   14]

# %%
xgboost_submit_result = './xgboost_result.csv'

new_encoder_map = {'No Churn':0, 'Competitor': 1, 'Dissatisfaction':2, 'Attitude': 3, 'Price':4, 'Other':5}

with open(xgboost_submit_result, 'w') as f:
    f.write('Customer ID,Churn Category\n')
    for i in range(len(df_test.values)):
        id = str(df_test.values[i]).replace('[\'', '')
        id = id.replace('\']', '')
        pred = new_encoder_map.get(list(encoder_map.keys())[list(encoder_map.values()).index(predict[i])])
        f.write(f'{id},{pred}\n')

# %%
from google.colab import files

files.download(xgboost_submit_result)

# %% [markdown]
# # **Test Data Analysis**

# %%
svm_test = pd.read_csv(svm_submit_result)
dnn_test = pd.read_csv(dnn_submit_result)
xgboost_test = pd.read_csv(xgboost_submit_result)

# %%
def plotResult(dataset1, dataset2, dataset3, method):
    fig, ax = plt.subplots(1, 3, figsize=(16, 6))
    fig.suptitle('Test Data Statistics')

    counts = []
    iter = 0
    for dataset in [dataset1, dataset2, dataset3]:
        freq = dataset.groupby('Churn Category').size()
        print(f'====== {method[iter]} ======')
        print(freq)
        print()

        counts = [count for _, count in freq.items()]
        x = np.arange(len(counts))
        ax[iter].bar(x, counts)
        ax[iter].set_xticks([0, 1, 2, 3, 4, 5])
        ax[iter].set_xticklabels(['No Churn', 'Competitor', 'Dissatisfaction', 'Attitude', 'Price', 'Other'], rotation=90)
        ax[iter].set_title(f'{method[iter]}')
        iter += 1

    plt.show()

# %%
plotResult(svm_test, dnn_test, xgboost_test, ['SVM', 'DNN', 'XGBoost'])
# Out:
# ====== SVM ======
# Churn Category
# 0    1061
# 1     182
# 2      58
# 3      56
# 4      37
# 5      15
# dtype: int64
#
# ====== DNN ======
# Churn Category
# 0    1111
# 1     188
# 2      36
# 3      36
# 4      20
# 5      18
# dtype: int64
#
# ====== XGBoost ======
# Churn Category
# 0    1113
# 1     198
# 2      34
# 3      40
# 4      14
# 5      10
# dtype: int64
