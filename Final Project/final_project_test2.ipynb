# %% [markdown]
# <a href="https://colab.research.google.com/github/Offliners/HTML_2021Fall/blob/main/Final%20Project/final_project_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Directory**
#
# ```
# data_dir
#     ├── data
#     │   ├── Test_IDs.csv
#     │   ├── ...
#     │   ├── status.csv
#     ├── statistics
#     │   ├── Churn Category_stat.png
#     │   ├── ...
#     │   ├── miss rate_stat.png
# ```

# %% [markdown]
# # **Display information of GPU**

# %%
# !nvidia-smi
# Out:
# Mon Jan 17 06:58:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # **Download Dataset**

# %%
# !mkdir "./data"
# !mkdir "./statistics"
# !gdown --id 1X5yz7QLAu4nttnCea4ALf6alae6Clv_o --output "./data/dataset.zip"
# !unzip -q "./data/dataset.zip" -d "./data"
# !rm "./data/dataset.zip"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X5yz7QLAu4nttnCea4ALf6alae6Clv_o
# To: /content/data/dataset.zip
# 100% 660k/660k [00:00<00:00, 97.4MB/s]

# %% [markdown]
# # **Import Some Packages**

# %%
import time
import numpy as np
import pandas as pd
from glob import glob
from collections import Counter
import collections
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report, plot_confusion_matrix
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer

# SMOTE
from imblearn.over_sampling import SMOTE, ADASYN, SVMSMOTE

# SVM
from sklearn.svm import SVC

# DNN
import torch
import torch.nn as nn
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from torchsummary import summary
from torch.optim.lr_scheduler import StepLR

# XGBoost
from xgboost import XGBClassifier

# %% [markdown]
# # **Set a Random Seed**

# %%
# Set a random seed for reproducibility
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # **CSV Files Combination**

# %%
train_path = './data/Train_IDs.csv'  # path to training data
test_path = './data/Test_IDs.csv'    # path to testing data

files = glob('./data/*.csv')
data_csv = []
data_csv.append(train_path)
for csv in files:
    if ('IDs' not in csv) and ('sample' not in csv) and ('population' not in csv) and ('result' not in csv):
        data_csv.append(csv)
  
print(data_csv)
df_list = [pd.read_csv(file) for file in data_csv]
# Out:
# ['./data/Train_IDs.csv', './data/services.csv', './data/location.csv', './data/satisfaction.csv', './data/demographics.csv', './data/status.csv']

# %%
result_total = df_list[0]
for df in df_list[1:]:
    result_total = pd.merge(result_total, df, how='outer', on='Customer ID')

result_total.to_csv('./data/result_total.csv') # Save combined all result to result_total.csv

# %%
# There are 7043 total customer data
print(result_total)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     0650-BWOZN      1.0  ...                  0.0     Competitor
# 1     0562-FGDCR      1.0  ...                  0.0     Competitor
# 2     6688-UZPWD      1.0  ...                  NaN       No Churn
# 3     2905-KFQUV      1.0  ...                  0.0     Competitor
# 4     9720-JJJOR      1.0  ...                  0.0       No Churn
# ...          ...      ...  ...                  ...            ...
# 7038  6778-EICRF      NaN  ...                  0.0            NaN
# 7039  0772-GYEQQ      NaN  ...                  2.0            NaN
# 7040  5666-CYCYZ      NaN  ...                  0.0            NaN
# 7041  4893-GYUJU      NaN  ...                  0.0            NaN
# 7042  3426-NIYYL      NaN  ...                  2.0            NaN
#
# [7043 rows x 48 columns]

# %%
# Train_IDs has 5634 customer data
result_train_total = df_list[0]
for df in df_list[1:]:
    result_train_total = pd.merge(result_train_total, df, how='left', on='Customer ID')

print(result_train_total)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     0650-BWOZN      1.0  ...                  0.0     Competitor
# 1     0562-FGDCR      1.0  ...                  0.0     Competitor
# 2     6688-UZPWD      1.0  ...                  NaN       No Churn
# 3     2905-KFQUV      1.0  ...                  0.0     Competitor
# 4     9720-JJJOR      1.0  ...                  0.0       No Churn
# ...          ...      ...  ...                  ...            ...
# 5629  1178-PZGAB      1.0  ...                  0.0            NaN
# 5630  4806-KEXQR      1.0  ...                  0.0            NaN
# 5631  8809-RIHDD      1.0  ...                  2.0       No Churn
# 5632  6663-JOCQO      1.0  ...                  3.0       No Churn
# 5633  7010-ZMVBF      1.0  ...                  0.0       No Churn
#
# [5634 rows x 48 columns]

# %%
# Train_IDs has 4226 customer data with label
result_train = df_list[0]
for df in df_list[1:]:
    result_train = pd.merge(result_train, df, how='right', on='Customer ID')

print(result_train)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     0650-BWOZN      NaN  ...                  0.0     Competitor
# 1     0562-FGDCR      1.0  ...                  0.0     Competitor
# 2     6688-UZPWD      1.0  ...                  NaN       No Churn
# 3     2905-KFQUV      1.0  ...                  0.0     Competitor
# 4     9720-JJJOR      NaN  ...                  0.0       No Churn
# ...          ...      ...  ...                  ...            ...
# 4221  3313-QKNKB      NaN  ...                  NaN       No Churn
# 4222  8668-KNZTI      NaN  ...                  NaN       No Churn
# 4223  8809-RIHDD      NaN  ...                  2.0       No Churn
# 4224  6663-JOCQO      NaN  ...                  3.0       No Churn
# 4225  7010-ZMVBF      1.0  ...                  0.0       No Churn
#
# [4226 rows x 48 columns]

# %%
# Train_IDs has 1408 customer data without label
result_train_miss = df_list[0]
for df in df_list[1:]:
    result_train_miss = pd.merge(result_train_miss, df, how='left', on='Customer ID')

result_train_miss = result_train_miss[result_train_miss['Churn Category'].isna()]

print(result_train_miss)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 6     0394-YONDK      1.0  ...                  NaN            NaN
# 7     0396-HUJBP      1.0  ...                  0.0            NaN
# 11    0684-AOSIH      1.0  ...                  2.0            NaN
# 14    1679-JRFBR      1.0  ...                  0.0            NaN
# 18    5533-NHFRF      NaN  ...                  0.0            NaN
# ...          ...      ...  ...                  ...            ...
# 5603  6330-JKLPC      1.0  ...                  NaN            NaN
# 5618  4549-ZDQYY      NaN  ...                  0.0            NaN
# 5622  9127-QRZMH      1.0  ...                  0.0            NaN
# 5629  1178-PZGAB      1.0  ...                  0.0            NaN
# 5630  4806-KEXQR      1.0  ...                  0.0            NaN
#
# [1408 rows x 48 columns]

# %%
# Test_Ids has 1409 customer data
df_test = pd.read_csv(test_path)
result_test = df_test
for df in df_list[1:]:
    result_test = pd.merge(result_test, df, how='left', on='Customer ID')

print(result_test)
# Out:
#      Customer ID  Count_x  ... Number of Dependents Churn Category
# 0     9938-EKRGF      1.0  ...                  0.0            NaN
# 1     7379-POKDZ      1.0  ...                  0.0            NaN
# 2     0654-HMSHN      1.0  ...                  NaN            NaN
# 3     2045-BMBTJ      1.0  ...                  3.0            NaN
# 4     0701-TJSEF      1.0  ...                  0.0            NaN
# ...          ...      ...  ...                  ...            ...
# 1404  4587-VVTOX      1.0  ...                  NaN            NaN
# 1405  7716-YTYHG      NaN  ...                  0.0            NaN
# 1406  7649-PHJVR      NaN  ...                  0.0            NaN
# 1407  7855-DIWPO      1.0  ...                  3.0            NaN
# 1408  8197-BFWVU      1.0  ...                  NaN            NaN
#
# [1409 rows x 48 columns]

# %%
print(result_total.dropna()) # Find customer with full data infomation
# Out:
#      Customer ID  Count_x  ... Number of Dependents   Churn Category
# 666   0454-OKRCT      1.0  ...                  2.0         No Churn
# 678   1735-XMJVH      1.0  ...                  0.0         No Churn
# 1799  1245-HARPS      1.0  ...                  0.0  Dissatisfaction
# 2805  8445-DNBAE      1.0  ...                  0.0       Competitor
# 2883  8708-XPXHZ      1.0  ...                  0.0         No Churn
# 3062  9522-ZSINC      1.0  ...                  0.0         No Churn
# 4297  0836-SEYLU      1.0  ...                  0.0         No Churn
# 5146  7274-RTAPZ      1.0  ...                  1.0         No Churn
#
# [8 rows x 48 columns]

# %%
result_cols = result_total.columns
print(result_cols)
# Out:
# Index(['Customer ID', 'Count_x', 'Quarter', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Count_y', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Satisfaction Score', 'Count',
#        'Gender', 'Age', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
#        'Number of Dependents', 'Churn Category'],
#       dtype='object')

# %%
missing = result_train_total.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_train_total.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of training dataset')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 0.8])  
plt.savefig(f'./statistics/miss rate_train_stat.png')  
plt.show()
plt.close()

# %%
missing = result_train.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_train.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of training dataset with label')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 0.8])  
plt.savefig(f'./statistics/miss rate_train_stat.png')  
plt.show()
plt.close()

# %%
missing = result_train_miss.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_train_miss.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of training dataset without label')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 1.4])  
plt.savefig(f'./statistics/miss rate_train_stat.png')  
plt.show()
plt.close()

# %%
missing = result_test.isnull().sum().reset_index().rename(columns={0:'missNum'})
missing['missRate'] = missing['missNum'] / result_test.shape[0]
miss_analy = missing[missing.missRate > 0].sort_values(by='missRate', ascending=False)

fig = plt.figure(figsize=(18, 6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align='center')

plt.title('Histogram of missing value of variables of test dataset')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]), list(miss_analy['index']))
plt.xticks(rotation=90)
for x, y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x, y + 0.12, '{:.2%}'.format(y), ha='center', rotation=90)    

plt.ylim([0, 1.4])  
plt.savefig(f'./statistics/miss rate_test_stat.png')  
plt.show()
plt.close()

# %% [markdown]
# # **Statistics and Data Preprocessing**

# %%
result_train_total_copy = result_train_total.copy(deep=True)
result_train_copy = result_train.copy(deep=True)
result_train_miss_copy = result_train_miss.copy(deep=True)
result_test_copy = result_test.copy(deep=True)
def label_statistics(label):
    freq = result_train_total.groupby(label).size()

    names = [name for name, _ in freq.items()]
    names.append('Nan')
    counts = [count for _, count in freq.items()]
    counts.append(len(result_train[label]) - sum(counts))

    fig = plt.figure(figsize=(8, 6))
    x = np.arange(len(names))
    plt.bar(x, counts)
    plt.xticks(x, names, rotation=15)
    plt.title(f'Statistics of {label}')
    plt.savefig(f'./statistics/Statistics of {label}.png')
    print(f'Statistics of {label}.png saved')
    plt.close()

# %%
need_statistics_col = ['Churn Category', 'Satisfaction Score', 
       'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
       'Number of Dependents', 'Country', 'State', 'City', 'Quarter',
       'Referred a Friend', 'Number of Referrals', 'Offer',
       'Phone Service', 'Multiple Lines', 'Internet Service', 'Internet Type',
       'Online Security', 'Online Backup', 'Device Protection Plan',
       'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
       'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
       'Payment Method', 'Zip Code']

# Replace NaN with the most frequent label
for need_col in need_statistics_col:
    label_statistics(need_col)

    # Encode target labels with value
    le = LabelEncoder()
    result_train_copy[need_col] = le.fit_transform(result_train_copy[need_col])

    if need_col == 'Churn Category':
        encoder_map = dict(zip(le.classes_, le.transform(le.classes_)))
    
    result_train_miss_copy[need_col] = le.fit_transform(result_train_miss_copy[need_col])
    result_test_copy[need_col] = le.fit_transform(result_test_copy[need_col])
# Out:
# Statistics of Churn Category.png saved
# Statistics of Satisfaction Score.png saved
# Statistics of Gender.png saved
# Statistics of Under 30.png saved
# Statistics of Senior Citizen.png saved
# Statistics of Married.png saved
# Statistics of Dependents.png saved
# Statistics of Number of Dependents.png saved
# Statistics of Country.png saved
# Statistics of State.png saved
# Statistics of City.png saved
# Statistics of Quarter.png saved
# Statistics of Referred a Friend.png saved
# Statistics of Number of Referrals.png saved
# Statistics of Offer.png saved
# Statistics of Phone Service.png saved
# Statistics of Multiple Lines.png saved
# Statistics of Internet Service.png saved
# Statistics of Internet Type.png saved
# Statistics of Online Security.png saved
# Statistics of Online Backup.png saved
# Statistics of Device Protection Plan.png saved
# Statistics of Premium Tech Support.png saved
# Statistics of Streaming TV.png saved
# Statistics of Streaming Movies.png saved
# Statistics of Streaming Music.png saved
# Statistics of Unlimited Data.png saved
# Statistics of Contract.png saved
# Statistics of Paperless Billing.png saved
# Statistics of Payment Method.png saved
# Statistics of Zip Code.png saved

# %%
population = pd.read_csv('./data/population.csv')
population = population.drop('Zip Code', axis=1)
population.rename({'ID':'Zip Code'}, axis=1, inplace=True)
result_train_copy = pd.merge(result_train_copy, population, how='left', on='Zip Code')
result_train_miss_copy = pd.merge(result_train_miss_copy, population, how='left', on='Zip Code')
result_test_copy = pd.merge(result_test_copy, population, how='left', on='Zip Code')

need_avg_col = [item for item in result_cols if item not in need_statistics_col]
need_avg_col.append('Population')

def data_imputation(train_dataset, miss_dataset, test_dataset, target):
    # imputer = IterativeImputer(max_iter=10, initial_strategy='median', imputation_order='random', random_state=seed)
    imputer = KNNImputer(n_neighbors=5, weights='distance')
    imputer.fit(train_dataset)
    train_dataset = imputer.transform(train_dataset)
    miss_dataset = imputer.transform(miss_dataset)
    test_dataset = imputer.transform(test_dataset)

    train_dataset = pd.DataFrame(train_dataset, columns=target)
    miss_dataset = pd.DataFrame(miss_dataset, columns=target)
    test_dataset = pd.DataFrame(test_dataset, columns=target)

    return train_dataset, miss_dataset, test_dataset

col_names = list(result_cols.values)
col_names.remove('Customer ID')
col_names.remove('Lat Long')
col_names.remove('Churn Category')
col_names.append('Population')

result_train_copy[col_names], result_train_miss_copy[col_names], result_test_copy[col_names] = data_imputation(result_train_copy[col_names], result_train_miss_copy[col_names], result_test_copy[col_names], col_names)

# %%
result_train_copy = result_train_copy.drop('Customer ID', axis=1)
result_train_copy = result_train_copy.drop('Lat Long', axis=1)
result_train_miss_copy = result_train_miss_copy.drop('Customer ID', axis=1)
result_train_miss_copy = result_train_miss_copy.drop('Lat Long', axis=1)
result_test_copy = result_test_copy.drop('Customer ID', axis=1)
result_test_copy = result_test_copy.drop('Lat Long', axis=1)

print(result_train_copy)
# Out:
#       Count_x  Quarter  ...  Churn Category  Population
# 0         1.0      1.0  ...               1       660.0
# 1         1.0      0.0  ...               1     37280.0
# 2         1.0      0.0  ...               3      2899.0
# 3         1.0      0.0  ...               1     26831.0
# 4         1.0      1.0  ...               3       660.0
# ...       ...      ...  ...             ...         ...
# 4221      1.0      1.0  ...               3       660.0
# 4222      1.0      1.0  ...               3       660.0
# 4223      1.0      1.0  ...               3       660.0
# 4224      1.0      1.0  ...               3       660.0
# 4225      1.0      0.0  ...               3     27047.0
#
# [4226 rows x 47 columns]

# %%
# Find the correlation of columns
cor_matrix = result_train_copy.corr().abs()
print(cor_matrix['Churn Category'])
# Out:
# Count_x                                   NaN
# Quarter                              0.026687
# Referred a Friend                    0.034992
# Number of Referrals                  0.065368
# Tenure in Months                     0.150621
# Offer                                0.035282
# Phone Service                        0.004287
# Avg Monthly Long Distance Charges    0.014581
# Multiple Lines                       0.021953
# Internet Service                     0.021609
# Internet Type                        0.038484
# Avg Monthly GB Download              0.042464
# Online Security                      0.061089
# Online Backup                        0.031315
# Device Protection Plan               0.028059
# Premium Tech Support                 0.053844
# Streaming TV                         0.008534
# Streaming Movies                     0.000321
# Streaming Music                      0.015176
# Unlimited Data                       0.013768
# Contract                             0.111203
# Paperless Billing                    0.009588
# Payment Method                       0.048995
# Monthly Charge                       0.076120
# Total Charges                        0.090457
# Total Refunds                        0.014488
# Total Extra Data Charges             0.025991
# Total Long Distance Charges          0.095889
# Total Revenue                        0.103179
# Count_y                                   NaN
# Country                              0.043073
# State                                0.054701
# City                                 0.035223
# Zip Code                             0.045957
# Latitude                             0.076492
# Longitude                            0.059734
# Satisfaction Score                   0.248098
# Count                                     NaN
# Gender                               0.005451
# Age                                  0.061110
# Under 30                             0.043659
# Senior Citizen                       0.004644
# Married                              0.037126
# Dependents                           0.087645
# Number of Dependents                 0.052063
# Churn Category                       1.000000
# Population                           0.014163
# Name: Churn Category, dtype: float64

# %%
plt.figure(figsize=(17, 13))
cor_matrix_copy = cor_matrix.copy(deep=True)
cor_matrix_copy.dropna()
ax = sns.heatmap(cor_matrix_copy, xticklabels=cor_matrix_copy.columns, yticklabels=cor_matrix_copy.columns, 
                 linewidths=0.2, cmap="RdYlGn_r", fmt="s")

plt.title("Correlation between variables")
plt.show()

# %%
useless_feature = [index for index, value in cor_matrix['Churn Category'].items() if value < 0.05 or pd.isnull(value)]
print(useless_feature)
# Out:
# ['Count_x', 'Quarter', 'Referred a Friend', 'Offer', 'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines', 'Internet Service', 'Internet Type', 'Avg Monthly GB Download', 'Online Backup', 'Device Protection Plan', 'Streaming TV', 'Streaming Movies', 'Streaming Music', 'Unlimited Data', 'Paperless Billing', 'Payment Method', 'Total Refunds', 'Total Extra Data Charges', 'Count_y', 'Country', 'City', 'Zip Code', 'Count', 'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Population']

# %%
def dropColumns(label):
    global result_train_copy, result_train_miss_copy, result_test_copy
    result_train_copy = result_train_copy.drop(label, axis=1)
    result_train_miss_copy = result_train_miss_copy.drop(label, axis=1)
    result_test_copy = result_test_copy.drop(label, axis=1)

# %%
# Throw away the data columns whose correlation to Churn Category is less than 0.05
for item in useless_feature:
    dropColumns(item)

# %%
result_train_copy.to_csv('./data/result_after_preprocessing.csv') # Save after preprocessing result to result_after_preprocessing.csv
feature_amount = len(result_train_copy.columns)

print(result_train_copy)
print(result_train_miss_copy)
print(result_test_copy)
# Out:
#       Number of Referrals  ...  Churn Category
# 0                    11.0  ...               1
# 1                     0.0  ...               1
# 2                     4.0  ...               3
# 3                     0.0  ...               1
# 4                    11.0  ...               3
# ...                   ...  ...             ...
# 4221                 11.0  ...               3
# 4222                 11.0  ...               3
# 4223                 11.0  ...               3
# 4224                 11.0  ...               3
# 4225                  8.0  ...               3
#
# [4226 rows x 17 columns]
#       Number of Referrals  ...  Churn Category
# 0                     0.0  ...               0
# 1                     2.0  ...               0
# 2                     1.0  ...               0
# 3                    10.0  ...               0
# 4                     0.0  ...               0
# ...                   ...  ...             ...
# 1403                  0.0  ...               0
# 1404                 12.0  ...               0
# 1405                  9.0  ...               0
# 1406                  0.0  ...               0
# 1407                  0.0  ...               0
#
# [1408 rows x 17 columns]
#       Number of Referrals  ...  Churn Category
# 0                     1.0  ...               0
# 1                     0.0  ...               0
# 2                     9.0  ...               0
# 3                     1.0  ...               0
# 4                     1.0  ...               0
# ...                   ...  ...             ...
# 1404                  0.0  ...               0
# 1405                 11.0  ...               0
# 1406                  1.0  ...               0
# 1407                  1.0  ...               0
# 1408                  0.0  ...               0
#
# [1409 rows x 17 columns]

# %% [markdown]
# # **Balance Data**

# %%
y_train = result_train_copy['Churn Category'].values
X_train = result_train_copy.drop('Churn Category', axis=1)

X_train_miss = result_train_miss_copy.drop('Churn Category', axis=1)

# %%
print(f"normal data distribution: {Counter(y_train)}")

smo = SVMSMOTE(random_state=seed)
X_train, y_train = smo.fit_resample(X_train, y_train)

print(f"SVMSMOTE data distribution: {Counter(y_train)}")

# ada = ADASYN(random_state=seed)
# X_train, y_train = ada.fit_resample(X_train, y_train)

# print(f"ADASYN data distribution: {Counter(y_train)}")

class_weight = dict(Counter(y_train))
# Out:
# normal data distribution: Counter({3: 3118, 1: 490, 0: 201, 2: 177, 5: 124, 4: 116})
# SVMSMOTE data distribution: Counter({1: 3118, 3: 3118, 0: 1943, 4: 1764, 5: 1646, 2: 1528})

# %% [markdown]
# # **Split and Standardize Data**

# %%
train_x, val_x, train_y, val_y = train_test_split(X_train, y_train, test_size=0.2, random_state=seed)

ss = StandardScaler().fit(train_x)
train_x = ss.transform(train_x)
val_x = ss.transform(val_x)
miss_x = ss.transform(X_train_miss)

X_test = result_test_copy.drop('Churn Category', axis=1)
X_test_std = ss.transform(X_test)

class_weight = {k: train_x.shape[0] / v for k, v in class_weight.items()}
class_weight = collections.OrderedDict(sorted(class_weight.items()))
print(class_weight)
# Out:
# OrderedDict([(0, 5.400411734431292), (1, 3.3652982681205903), (2, 6.867146596858639), (3, 3.3652982681205903), (4, 5.948412698412699), (5, 6.374848116646415)])

# %% [markdown]
# # **SVM Train**

# %%
svm = SVC(kernel='rbf', gamma=0.1, C=10, class_weight=class_weight)

start_time = time.time()
model = svm.fit(train_x, train_y)
end_time = time.time()

print(f'Training use {round(end_time - start_time, 3)}s')
# Out:
# Training use 5.187s

# %%
y_train_predict = svm.predict(train_x)
Ein = np.mean(np.array(y_train_predict) != train_y)
F1in = metrics.f1_score(train_y, y_train_predict, average='macro')  
print(f'Ein = {round(Ein, 5)}')
print(f'F1_in = {round(F1in, 5)}')

y_val_predict = svm.predict(val_x)
Eval = np.mean(np.array(y_val_predict) != val_y)
F1val = metrics.f1_score(val_y, y_val_predict, average='macro')  
print(f'Eval = {round(Eval, 5)}')
print(f'F1_val = {round(F1val, 5)}')
# Out:
# Ein = 0.12694
# F1_in = 0.87445
# Eval = 0.16502
# F1_val = 0.83861

# %%
plot_confusion_matrix(model, train_x, train_y)
plot_confusion_matrix(model, val_x, val_y)
print(encoder_map)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}

# %%
print(classification_report(train_y, y_train_predict))
print(classification_report(val_y, y_val_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94      1560
#            1       0.97      0.83      0.89      2480
#            2       0.95      0.73      0.83      1222
#            3       0.96      0.81      0.88      2517
#            4       0.60      0.98      0.74      1409
#            5       0.95      0.98      0.96      1305
#
#     accuracy                           0.87     10493
#    macro avg       0.89      0.88      0.87     10493
# weighted avg       0.90      0.87      0.88     10493
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       383
#            1       0.92      0.77      0.84       638
#            2       0.89      0.73      0.80       306
#            3       0.90      0.74      0.81       601
#            4       0.61      0.96      0.75       355
#            5       0.92      0.96      0.94       341
#
#     accuracy                           0.83      2624
#    macro avg       0.85      0.85      0.84      2624
# weighted avg       0.86      0.83      0.84      2624

# %% [markdown]
# # **SVM Test**

# %%
y_test = svm.predict(X_test_std)
plot_confusion_matrix(model, X_test_std, y_test)
print(encoder_map)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}

# %%
svm_submit_result = './svm_result.csv'

new_encoder_map = {'No Churn':0, 'Competitor': 1, 'Dissatisfaction':2, 'Attitude': 3, 'Price':4, 'Other':5}

with open(svm_submit_result, 'w') as f:
    f.write('Customer ID,Churn Category\n')
    for i in range(len(df_test.values)):
        id = str(df_test.values[i]).replace('[\'', '')
        id = id.replace('\']', '')
        pred = new_encoder_map.get(list(encoder_map.keys())[list(encoder_map.values()).index(y_test[i])])
        f.write(f'{id},{pred}\n')

# %%
from google.colab import files

files.download(svm_submit_result)

# %% [markdown]
# # **Deep Neural Network Train**

# %%
class IBMDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int)
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.layer1 = nn.Linear(feature_amount - 1, 256)
        self.layer2 = nn.Linear(256, 128)
        self.layer3 = nn.Linear(128, 64)
        self.bn1 = nn.BatchNorm1d(256)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(64)
        self.out = nn.Linear(64, 6)
        self.dp = nn.Dropout(0.1)
        self.act_fn = nn.LeakyReLU()

    def forward(self, x):
        x = self.layer1(x)
        x = self.act_fn(x)
        x = self.bn1(x)
        x = self.dp(x)

        x = self.layer2(x)
        x = self.act_fn(x)
        x = self.bn2(x)
        x = self.dp(x)

        x = self.layer3(x)
        x = self.act_fn(x)
        x = self.bn3(x)
        x = self.dp(x)
        
        x = self.out(x)
        
        return x

# classifier = Classifier()
# summary(classifier, X_train.shape, device="cpu")

# %%
def get_pseudo_labels(dataset, model, batch_size, threshold=0.99):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    model.eval()
    softmax = nn.Softmax(dim=-1)

    pseudo_x = []
    pseudo_y = []
    for i, data in enumerate(data_loader):
        inputs = data

        with torch.no_grad():
            logits = model(inputs.to(device))

        probs = softmax(logits)
        label = torch.where(torch.max(probs, dim=1)[0] > threshold, torch.argmax(probs,dim=1), -1)
        label = label.cpu()
        for j in range(len(label)):
            if label[j] != -1:
                pseudo_x.append(data[j])
                pseudo_y.append(label[j])

    model.train()
    print(f"Pseudo Labeling : {len(pseudo_x)}")
    if len(pseudo_x) > 0:
        flag = 1
        pseudo_dataset = IBMDataset(torch.stack(pseudo_x, dim=0).numpy(), np.array(pseudo_y))
        return pseudo_dataset, len(pseudo_x), flag
    else:
        flag = 0
        return None, 0, flag

# %%
VAL_RATIO = 0.2
BATCH_SIZE = 64

percent = int(X_train.shape[0] * (1 - VAL_RATIO))
train_x, train_y, val_x, val_y = X_train[:percent], y_train[:percent], X_train[percent:], y_train[percent:]

ss = StandardScaler().fit(train_x)
train_x = ss.transform(train_x)
miss_x = ss.transform(X_train_miss)
val_x = ss.transform(val_x)
X_test_std = ss.transform(X_test)

print('Size of training set: {}'.format(train_x.shape))
print('Size of training set: {}'.format(miss_x.shape))
print('Size of validation set: {}'.format(val_x.shape))
# Out:
# Size of training set: (10493, 16)
# Size of training set: (1408, 16)
# Size of validation set: (2624, 16)

# %%
train_set = IBMDataset(train_x, train_y)
miss_set = IBMDataset(miss_x, None)
val_set = IBMDataset(val_x, val_y)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) # only shuffle the training data
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# %%
# get device 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'DEVICE: {device}')

# training parameters
num_epoch = 3000             # number of training epoch
learning_rate = 0.001       # learning rate
callback_num = 200

# the path where checkpoint saved
model_path = './best_model.ckpt'

# create model, define a loss function, and optimizer
model = Classifier().to(device)
class_weight = [v for k, v in class_weight.items()]
criterion = nn.CrossEntropyLoss(weight=torch.FloatTensor(class_weight).to(device))
optimizer = torch.optim.Adam(model.parameters(), weight_decay=5e-4, lr=learning_rate)
scheduler = StepLR(optimizer, step_size=len(train_loader) * 100, gamma=0.1)
# Out:
# DEVICE: cuda

# %%
best_acc = 0.0
count = 0
start_time = time.time()
train_acc_list = []
train_loss_list = []
val_acc_list = []
val_loss_list = []
for epoch in range(num_epoch):
    train_acc = 0.0
    train_loss = 0.0
    val_acc = 0.0
    val_loss = 0.0

    # Pseudo Label
    pseudo_set, add_num, flag = get_pseudo_labels(miss_set, model, BATCH_SIZE)
    if flag:
        concat_dataset = ConcatDataset([train_set, pseudo_set])
        train_loader_semi = DataLoader(concat_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    else:
        train_loader_semi = train_loader
    # train_loader_semi = train_loader
    # training
    model.train() # set the model to training mode
    for i, data in enumerate(train_loader_semi):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        batch_loss = criterion(outputs, labels)
        _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
        batch_loss.backward() 
        optimizer.step()
        scheduler.step()

        train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
        train_loss += batch_loss.item()

    # validation
    if len(val_set) > 0:
        model.eval() # set the model to evaluation mode
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                batch_loss = criterion(outputs, labels) 
                _, val_pred = torch.max(outputs, 1) 
            
                val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                val_loss += batch_loss.item()

            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/(len(train_set) + add_num), train_loss/len(train_loader_semi), val_acc/len(val_set), val_loss/len(val_loader)
            ))

            # Record Training and validation info
            train_acc_list.append(train_acc/(len(train_set) + add_num))
            train_loss_list.append(train_loss/len(train_loader_semi))
            val_acc_list.append(val_acc/len(val_set))
            val_loss_list.append(val_loss/len(val_loader))

            # if the model improves, save a checkpoint at this epoch
            count += 1
            if val_acc > best_acc:
                count = 0
                best_acc = val_acc
                torch.save(model.state_dict(), model_path)
                print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))
    else:
        print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
            epoch + 1, num_epoch, train_acc/(len(train_set) + add_num), train_loss/len(train_loader_semi)
        ))

    if count > callback_num:
        break

# if not validating, save the last epoch
if len(val_set) == 0:
    torch.save(model.state_dict(), model_path)
    print('saving model at last epoch')

end_time = time.time()
# Out:
# Pseudo Labeling : 0
# [001/3000] Train Acc: 0.524540 Loss: 1.299238 | Val Acc: 0.060595 loss: 2.188965
# saving model with acc 0.061
# Pseudo Labeling : 0
# [002/3000] Train Acc: 0.600591 Loss: 1.072885 | Val Acc: 0.100991 loss: 2.550400
# saving model with acc 0.101
# Pseudo Labeling : 7
# [003/3000] Train Acc: 0.630571 Loss: 0.971232 | Val Acc: 0.143293 loss: 2.568161
# saving model with acc 0.143
# Pseudo Labeling : 16
# [004/3000] Train Acc: 0.654106 Loss: 0.901009 | Val Acc: 0.174162 loss: 2.533332
# saving model with acc 0.174
# Pseudo Labeling : 52
# [005/3000] Train Acc: 0.676339 Loss: 0.839893 | Val Acc: 0.173018 loss: 2.502095
# Pseudo Labeling : 104
# [006/3000] Train Acc: 0.695197 Loss: 0.802059 | Val Acc: 0.189024 loss: 2.450151
# saving model with acc 0.189
# Pseudo Labeling : 131
# [007/3000] Train Acc: 0.703125 Loss: 0.774511 | Val Acc: 0.183689 loss: 2.444738
# Pseudo Labeling : 137
# [008/3000] Train Acc: 0.717215 Loss: 0.734244 | Val Acc: 0.213796 loss: 2.398674
# saving model with acc 0.214
# Pseudo Labeling : 119
# [009/3000] Train Acc: 0.715417 Loss: 0.716694 | Val Acc: 0.214939 loss: 2.392753
# saving model with acc 0.215
# Pseudo Labeling : 167
# [010/3000] Train Acc: 0.729737 Loss: 0.697322 | Val Acc: 0.238567 loss: 2.276599
# saving model with acc 0.239
# Pseudo Labeling : 189
# [011/3000] Train Acc: 0.734507 Loss: 0.682369 | Val Acc: 0.230183 loss: 2.323484
# Pseudo Labeling : 227
# [012/3000] Train Acc: 0.737873 Loss: 0.662487 | Val Acc: 0.204268 loss: 2.338847
# Pseudo Labeling : 246
# [013/3000] Train Acc: 0.745786 Loss: 0.645138 | Val Acc: 0.212652 loss: 2.377664
# Pseudo Labeling : 237
# [014/3000] Train Acc: 0.747530 Loss: 0.644420 | Val Acc: 0.248095 loss: 2.288111
# saving model with acc 0.248
# Pseudo Labeling : 285
# [015/3000] Train Acc: 0.753665 Loss: 0.620126 | Val Acc: 0.219512 loss: 2.452256
# Pseudo Labeling : 399
# [016/3000] Train Acc: 0.762578 Loss: 0.606262 | Val Acc: 0.260290 loss: 2.155097
# saving model with acc 0.260
# Pseudo Labeling : 324
# [017/3000] Train Acc: 0.761949 Loss: 0.607177 | Val Acc: 0.269817 loss: 2.186662
# saving model with acc 0.270
# Pseudo Labeling : 271
# [018/3000] Train Acc: 0.763378 Loss: 0.596109 | Val Acc: 0.274009 loss: 2.213695
# saving model with acc 0.274
# Pseudo Labeling : 335
# [019/3000] Train Acc: 0.772349 Loss: 0.578108 | Val Acc: 0.256098 loss: 2.239763
# Pseudo Labeling : 370
# [020/3000] Train Acc: 0.772346 Loss: 0.569446 | Val Acc: 0.259909 loss: 2.104366
# Pseudo Labeling : 331
# [021/3000] Train Acc: 0.774205 Loss: 0.561503 | Val Acc: 0.269817 loss: 2.069814
# Pseudo Labeling : 341
# [022/3000] Train Acc: 0.779398 Loss: 0.558338 | Val Acc: 0.279345 loss: 2.105115
# saving model with acc 0.279
# Pseudo Labeling : 368
# [023/3000] Train Acc: 0.779302 Loss: 0.552932 | Val Acc: 0.281250 loss: 2.132272
# saving model with acc 0.281
# Pseudo Labeling : 383
# [024/3000] Train Acc: 0.776848 Loss: 0.550349 | Val Acc: 0.292302 loss: 2.136980
# saving model with acc 0.292
# Pseudo Labeling : 372
# [025/3000] Train Acc: 0.780120 Loss: 0.554692 | Val Acc: 0.273247 loss: 2.113221
# Pseudo Labeling : 348
# [026/3000] Train Acc: 0.780186 Loss: 0.545873 | Val Acc: 0.291540 loss: 2.049835
# Pseudo Labeling : 346
# [027/3000] Train Acc: 0.789648 Loss: 0.530690 | Val Acc: 0.253811 loss: 2.259173
# Pseudo Labeling : 407
# [028/3000] Train Acc: 0.789450 Loss: 0.536317 | Val Acc: 0.309070 loss: 2.056349
# saving model with acc 0.309
# Pseudo Labeling : 403
# [029/3000] Train Acc: 0.787078 Loss: 0.528869 | Val Acc: 0.290015 loss: 1.981878
# Pseudo Labeling : 417
# [030/3000] Train Acc: 0.795967 Loss: 0.517520 | Val Acc: 0.341082 loss: 2.014010
# saving model with acc 0.341
# Pseudo Labeling : 467
# [031/3000] Train Acc: 0.797901 Loss: 0.509173 | Val Acc: 0.329649 loss: 1.913477
# Pseudo Labeling : 429
# [032/3000] Train Acc: 0.788867 Loss: 0.519179 | Val Acc: 0.286966 loss: 2.103943
# Pseudo Labeling : 437
# [033/3000] Train Acc: 0.793230 Loss: 0.505136 | Val Acc: 0.305640 loss: 1.971458
# Pseudo Labeling : 412
# [034/3000] Train Acc: 0.799541 Loss: 0.497733 | Val Acc: 0.327363 loss: 2.034275
# Pseudo Labeling : 449
# [035/3000] Train Acc: 0.797752 Loss: 0.496515 | Val Acc: 0.314024 loss: 1.996552
# Pseudo Labeling : 502
# [036/3000] Train Acc: 0.797090 Loss: 0.500384 | Val Acc: 0.346799 loss: 1.824866
# saving model with acc 0.347
# Pseudo Labeling : 476
# [037/3000] Train Acc: 0.802808 Loss: 0.485865 | Val Acc: 0.315168 loss: 2.042739
# Pseudo Labeling : 479
# [038/3000] Train Acc: 0.799945 Loss: 0.490592 | Val Acc: 0.356707 loss: 1.886748
# saving model with acc 0.357
# Pseudo Labeling : 478
# [039/3000] Train Acc: 0.800474 Loss: 0.488817 | Val Acc: 0.341082 loss: 2.049596
# Pseudo Labeling : 530
# [040/3000] Train Acc: 0.802867 Loss: 0.489442 | Val Acc: 0.352515 loss: 1.829240
# Pseudo Labeling : 483
# [041/3000] Train Acc: 0.801203 Loss: 0.487085 | Val Acc: 0.333841 loss: 1.853062
# Pseudo Labeling : 447
# [042/3000] Train Acc: 0.803291 Loss: 0.483028 | Val Acc: 0.515625 loss: 1.900443
# saving model with acc 0.516
# Pseudo Labeling : 528
# [043/3000] Train Acc: 0.807458 Loss: 0.479476 | Val Acc: 0.365473 loss: 1.870136
# Pseudo Labeling : 534
# [044/3000] Train Acc: 0.804571 Loss: 0.481107 | Val Acc: 0.352896 loss: 1.897735
# Pseudo Labeling : 444
# [045/3000] Train Acc: 0.806985 Loss: 0.467326 | Val Acc: 0.352134 loss: 2.000369
# Pseudo Labeling : 524
# [046/3000] Train Acc: 0.808296 Loss: 0.475637 | Val Acc: 0.367759 loss: 2.018717
# Pseudo Labeling : 520
# [047/3000] Train Acc: 0.809407 Loss: 0.471450 | Val Acc: 0.355945 loss: 1.891529
# Pseudo Labeling : 522
# [048/3000] Train Acc: 0.810168 Loss: 0.472067 | Val Acc: 0.382622 loss: 1.854491
# Pseudo Labeling : 512
# [049/3000] Train Acc: 0.811268 Loss: 0.458429 | Val Acc: 0.356707 loss: 1.849151
# Pseudo Labeling : 503
# [050/3000] Train Acc: 0.808749 Loss: 0.468510 | Val Acc: 0.369284 loss: 1.825673
# Pseudo Labeling : 552
# [051/3000] Train Acc: 0.811770 Loss: 0.458569 | Val Acc: 0.378430 loss: 1.855194
# Pseudo Labeling : 488
# [052/3000] Train Acc: 0.813314 Loss: 0.459415 | Val Acc: 0.360518 loss: 1.913682
# Pseudo Labeling : 557
# [053/3000] Train Acc: 0.812036 Loss: 0.459779 | Val Acc: 0.375762 loss: 1.816497
# Pseudo Labeling : 551
# [054/3000] Train Acc: 0.814741 Loss: 0.454841 | Val Acc: 0.377668 loss: 1.901456
# Pseudo Labeling : 594
# [055/3000] Train Acc: 0.816542 Loss: 0.449445 | Val Acc: 0.368140 loss: 1.876044
# Pseudo Labeling : 559
# [056/3000] Train Acc: 0.813789 Loss: 0.458471 | Val Acc: 0.376524 loss: 1.739867
# Pseudo Labeling : 595
# [057/3000] Train Acc: 0.811778 Loss: 0.460913 | Val Acc: 0.373857 loss: 1.969528
# Pseudo Labeling : 581
# [058/3000] Train Acc: 0.816868 Loss: 0.459844 | Val Acc: 0.407012 loss: 1.800408
# Pseudo Labeling : 598
# [059/3000] Train Acc: 0.818051 Loss: 0.453472 | Val Acc: 0.377668 loss: 1.750887
# Pseudo Labeling : 551
# [060/3000] Train Acc: 0.812658 Loss: 0.460112 | Val Acc: 0.385290 loss: 1.873067
# Pseudo Labeling : 576
# [061/3000] Train Acc: 0.812088 Loss: 0.454941 | Val Acc: 0.394055 loss: 1.726101
# Pseudo Labeling : 554
# [062/3000] Train Acc: 0.820223 Loss: 0.441597 | Val Acc: 0.380716 loss: 1.816962
# Pseudo Labeling : 605
# [063/3000] Train Acc: 0.821680 Loss: 0.438111 | Val Acc: 0.387957 loss: 1.895704
# Pseudo Labeling : 598
# [064/3000] Train Acc: 0.815075 Loss: 0.449155 | Val Acc: 0.394436 loss: 1.781965
# Pseudo Labeling : 551
# [065/3000] Train Acc: 0.820898 Loss: 0.440557 | Val Acc: 0.377287 loss: 1.922831
# Pseudo Labeling : 588
# [066/3000] Train Acc: 0.819691 Loss: 0.444952 | Val Acc: 0.394436 loss: 1.794408
# Pseudo Labeling : 666
# [067/3000] Train Acc: 0.817636 Loss: 0.445824 | Val Acc: 0.388338 loss: 1.823878
# Pseudo Labeling : 599
# [068/3000] Train Acc: 0.824648 Loss: 0.433525 | Val Acc: 0.364329 loss: 1.900703
# Pseudo Labeling : 617
# [069/3000] Train Acc: 0.818812 Loss: 0.443374 | Val Acc: 0.382241 loss: 1.859232
# Pseudo Labeling : 642
# [070/3000] Train Acc: 0.816255 Loss: 0.439363 | Val Acc: 0.384146 loss: 1.762669
# Pseudo Labeling : 688
# [071/3000] Train Acc: 0.821572 Loss: 0.439737 | Val Acc: 0.375762 loss: 1.754850
# Pseudo Labeling : 616
# [072/3000] Train Acc: 0.826357 Loss: 0.434363 | Val Acc: 0.394055 loss: 1.761799
# Pseudo Labeling : 646
# [073/3000] Train Acc: 0.824311 Loss: 0.427741 | Val Acc: 0.354040 loss: 2.017172
# Pseudo Labeling : 589
# [074/3000] Train Acc: 0.826746 Loss: 0.432026 | Val Acc: 0.375381 loss: 1.852759
# Pseudo Labeling : 644
# [075/3000] Train Acc: 0.822304 Loss: 0.440468 | Val Acc: 0.408155 loss: 1.689561
# Pseudo Labeling : 594
# [076/3000] Train Acc: 0.815820 Loss: 0.443651 | Val Acc: 0.409680 loss: 1.737403
# Pseudo Labeling : 597
# [077/3000] Train Acc: 0.822543 Loss: 0.430660 | Val Acc: 0.376143 loss: 1.829312
# Pseudo Labeling : 632
# [078/3000] Train Acc: 0.820135 Loss: 0.438145 | Val Acc: 0.406250 loss: 1.706137
# Pseudo Labeling : 580
# [079/3000] Train Acc: 0.824438 Loss: 0.425952 | Val Acc: 0.399390 loss: 1.712909
# Pseudo Labeling : 636
# [080/3000] Train Acc: 0.824782 Loss: 0.423420 | Val Acc: 0.382241 loss: 1.862376
# Pseudo Labeling : 645
# [081/3000] Train Acc: 0.823487 Loss: 0.427740 | Val Acc: 0.384527 loss: 1.876048
# Pseudo Labeling : 677
# [082/3000] Train Acc: 0.821038 Loss: 0.435315 | Val Acc: 0.360137 loss: 1.830477
# Pseudo Labeling : 681
# [083/3000] Train Acc: 0.821997 Loss: 0.437601 | Val Acc: 0.372713 loss: 1.707866
# Pseudo Labeling : 621
# [084/3000] Train Acc: 0.821846 Loss: 0.421774 | Val Acc: 0.389482 loss: 1.768309
# Pseudo Labeling : 624
# [085/3000] Train Acc: 0.823424 Loss: 0.428957 | Val Acc: 0.386052 loss: 1.811907
# Pseudo Labeling : 648
# [086/3000] Train Acc: 0.827394 Loss: 0.425047 | Val Acc: 0.373095 loss: 1.813436
# Pseudo Labeling : 643
# [087/3000] Train Acc: 0.826688 Loss: 0.425212 | Val Acc: 0.378430 loss: 1.881161
# Pseudo Labeling : 660
# [088/3000] Train Acc: 0.822290 Loss: 0.430994 | Val Acc: 0.405488 loss: 1.766173
# Pseudo Labeling : 609
# [089/3000] Train Acc: 0.825347 Loss: 0.427493 | Val Acc: 0.392530 loss: 1.874703
# Pseudo Labeling : 634
# [090/3000] Train Acc: 0.821875 Loss: 0.430127 | Val Acc: 0.393293 loss: 1.771274
# Pseudo Labeling : 682
# [091/3000] Train Acc: 0.823177 Loss: 0.425683 | Val Acc: 0.407012 loss: 1.688642
# Pseudo Labeling : 683
# [092/3000] Train Acc: 0.823819 Loss: 0.430493 | Val Acc: 0.416159 loss: 1.770078
# Pseudo Labeling : 682
# [093/3000] Train Acc: 0.826219 Loss: 0.431816 | Val Acc: 0.407774 loss: 1.724937
# Pseudo Labeling : 687
# [094/3000] Train Acc: 0.825760 Loss: 0.420326 | Val Acc: 0.365854 loss: 1.841463
# Pseudo Labeling : 691
# [095/3000] Train Acc: 0.830025 Loss: 0.414706 | Val Acc: 0.399009 loss: 1.812119
# Pseudo Labeling : 674
# [096/3000] Train Acc: 0.828244 Loss: 0.416221 | Val Acc: 0.371189 loss: 1.863282
# Pseudo Labeling : 638
# [097/3000] Train Acc: 0.831731 Loss: 0.393261 | Val Acc: 0.391006 loss: 1.785310
# Pseudo Labeling : 737
# [098/3000] Train Acc: 0.844791 Loss: 0.372464 | Val Acc: 0.397485 loss: 1.766774
# Pseudo Labeling : 695
# [099/3000] Train Acc: 0.846353 Loss: 0.366634 | Val Acc: 0.411204 loss: 1.747069
# Pseudo Labeling : 715
# [100/3000] Train Acc: 0.848947 Loss: 0.364344 | Val Acc: 0.415396 loss: 1.740581
# Pseudo Labeling : 714
# [101/3000] Train Acc: 0.851968 Loss: 0.360393 | Val Acc: 0.408918 loss: 1.747412
# Pseudo Labeling : 719
# [102/3000] Train Acc: 0.853104 Loss: 0.357025 | Val Acc: 0.433689 loss: 1.671292
# Pseudo Labeling : 752
# [103/3000] Train Acc: 0.848555 Loss: 0.360502 | Val Acc: 0.447790 loss: 1.622191
# Pseudo Labeling : 725
# [104/3000] Train Acc: 0.854698 Loss: 0.354663 | Val Acc: 0.423399 loss: 1.702992
# Pseudo Labeling : 737
# [105/3000] Train Acc: 0.855476 Loss: 0.349964 | Val Acc: 0.439787 loss: 1.649751
# Pseudo Labeling : 775
# [106/3000] Train Acc: 0.857650 Loss: 0.348856 | Val Acc: 0.440930 loss: 1.643452
# Pseudo Labeling : 739
# [107/3000] Train Acc: 0.857016 Loss: 0.343650 | Val Acc: 0.441311 loss: 1.662798
# Pseudo Labeling : 741
# [108/3000] Train Acc: 0.853748 Loss: 0.350641 | Val Acc: 0.447790 loss: 1.624970
# Pseudo Labeling : 728
# [109/3000] Train Acc: 0.852598 Loss: 0.345758 | Val Acc: 0.449695 loss: 1.639557
# Pseudo Labeling : 766
# [110/3000] Train Acc: 0.852118 Loss: 0.346298 | Val Acc: 0.438643 loss: 1.640276
# Pseudo Labeling : 772
# [111/3000] Train Acc: 0.855304 Loss: 0.350862 | Val Acc: 0.448552 loss: 1.642898
# Pseudo Labeling : 774
# [112/3000] Train Acc: 0.857992 Loss: 0.348288 | Val Acc: 0.438643 loss: 1.705754
# Pseudo Labeling : 778
# [113/3000] Train Acc: 0.856978 Loss: 0.339400 | Val Acc: 0.440549 loss: 1.687421
# Pseudo Labeling : 788
# [114/3000] Train Acc: 0.856218 Loss: 0.340695 | Val Acc: 0.442073 loss: 1.641043
# Pseudo Labeling : 732
# [115/3000] Train Acc: 0.858085 Loss: 0.339113 | Val Acc: 0.450457 loss: 1.658456
# Pseudo Labeling : 787
# [116/3000] Train Acc: 0.856826 Loss: 0.339462 | Val Acc: 0.448933 loss: 1.643804
# Pseudo Labeling : 765
# [117/3000] Train Acc: 0.851306 Loss: 0.344288 | Val Acc: 0.444360 loss: 1.692866
# Pseudo Labeling : 754
# [118/3000] Train Acc: 0.855339 Loss: 0.340401 | Val Acc: 0.451982 loss: 1.681198
# Pseudo Labeling : 756
# [119/3000] Train Acc: 0.856965 Loss: 0.335193 | Val Acc: 0.447790 loss: 1.665238
# Pseudo Labeling : 749
# [120/3000] Train Acc: 0.855542 Loss: 0.335276 | Val Acc: 0.457698 loss: 1.626870
# Pseudo Labeling : 808
# [121/3000] Train Acc: 0.857800 Loss: 0.340938 | Val Acc: 0.456555 loss: 1.625055
# Pseudo Labeling : 809
# [122/3000] Train Acc: 0.855866 Loss: 0.338028 | Val Acc: 0.454649 loss: 1.665920
# Pseudo Labeling : 794
# [123/3000] Train Acc: 0.860902 Loss: 0.330765 | Val Acc: 0.455030 loss: 1.693686
# Pseudo Labeling : 789
# [124/3000] Train Acc: 0.856852 Loss: 0.344006 | Val Acc: 0.458841 loss: 1.628932
# Pseudo Labeling : 753
# [125/3000] Train Acc: 0.854526 Loss: 0.336997 | Val Acc: 0.471418 loss: 1.616313
# Pseudo Labeling : 765
# [126/3000] Train Acc: 0.854503 Loss: 0.342234 | Val Acc: 0.461128 loss: 1.641710
# Pseudo Labeling : 779
# [127/3000] Train Acc: 0.861604 Loss: 0.333106 | Val Acc: 0.461509 loss: 1.622654
# Pseudo Labeling : 787
# [128/3000] Train Acc: 0.859397 Loss: 0.338972 | Val Acc: 0.463796 loss: 1.637619
# Pseudo Labeling : 785
# [129/3000] Train Acc: 0.861589 Loss: 0.333728 | Val Acc: 0.453887 loss: 1.675914
# Pseudo Labeling : 799
# [130/3000] Train Acc: 0.858395 Loss: 0.336549 | Val Acc: 0.456174 loss: 1.696038
# Pseudo Labeling : 795
# [131/3000] Train Acc: 0.861977 Loss: 0.330026 | Val Acc: 0.474085 loss: 1.583433
# Pseudo Labeling : 800
# [132/3000] Train Acc: 0.857345 Loss: 0.337449 | Val Acc: 0.477515 loss: 1.584033
# Pseudo Labeling : 785
# [133/3000] Train Acc: 0.859727 Loss: 0.334184 | Val Acc: 0.467607 loss: 1.651582
# Pseudo Labeling : 784
# [134/3000] Train Acc: 0.861843 Loss: 0.329872 | Val Acc: 0.461509 loss: 1.696475
# Pseudo Labeling : 801
# [135/3000] Train Acc: 0.859394 Loss: 0.329582 | Val Acc: 0.461890 loss: 1.666824
# Pseudo Labeling : 821
# [136/3000] Train Acc: 0.857433 Loss: 0.332896 | Val Acc: 0.463034 loss: 1.646878
# Pseudo Labeling : 804
# [137/3000] Train Acc: 0.860848 Loss: 0.331420 | Val Acc: 0.472561 loss: 1.618709
# Pseudo Labeling : 813
# [138/3000] Train Acc: 0.857686 Loss: 0.335872 | Val Acc: 0.468369 loss: 1.594839
# Pseudo Labeling : 839
# [139/3000] Train Acc: 0.865867 Loss: 0.325910 | Val Acc: 0.471799 loss: 1.608785
# Pseudo Labeling : 831
# [140/3000] Train Acc: 0.860297 Loss: 0.329256 | Val Acc: 0.466082 loss: 1.634701
# Pseudo Labeling : 812
# [141/3000] Train Acc: 0.862273 Loss: 0.325260 | Val Acc: 0.457317 loss: 1.680042
# Pseudo Labeling : 793
# [142/3000] Train Acc: 0.861510 Loss: 0.332733 | Val Acc: 0.458079 loss: 1.684194
# Pseudo Labeling : 814
# [143/3000] Train Acc: 0.858583 Loss: 0.330373 | Val Acc: 0.456555 loss: 1.667342
# Pseudo Labeling : 834
# [144/3000] Train Acc: 0.855390 Loss: 0.328498 | Val Acc: 0.467226 loss: 1.641434
# Pseudo Labeling : 806
# [145/3000] Train Acc: 0.862731 Loss: 0.328115 | Val Acc: 0.463415 loss: 1.656173
# Pseudo Labeling : 841
# [146/3000] Train Acc: 0.864655 Loss: 0.326061 | Val Acc: 0.461128 loss: 1.633318
# Pseudo Labeling : 810
# [147/3000] Train Acc: 0.857737 Loss: 0.333321 | Val Acc: 0.455030 loss: 1.699441
# Pseudo Labeling : 808
# [148/3000] Train Acc: 0.861694 Loss: 0.326003 | Val Acc: 0.466082 loss: 1.643175
# Pseudo Labeling : 839
# [149/3000] Train Acc: 0.863837 Loss: 0.331323 | Val Acc: 0.469512 loss: 1.661670
# Pseudo Labeling : 810
# [150/3000] Train Acc: 0.859506 Loss: 0.329201 | Val Acc: 0.467226 loss: 1.684884
# Pseudo Labeling : 828
# [151/3000] Train Acc: 0.857610 Loss: 0.334089 | Val Acc: 0.464939 loss: 1.690524
# Pseudo Labeling : 833
# [152/3000] Train Acc: 0.861911 Loss: 0.321278 | Val Acc: 0.462271 loss: 1.686152
# Pseudo Labeling : 833
# [153/3000] Train Acc: 0.860586 Loss: 0.325270 | Val Acc: 0.462271 loss: 1.676309
# Pseudo Labeling : 819
# [154/3000] Train Acc: 0.858027 Loss: 0.328893 | Val Acc: 0.467988 loss: 1.654172
# Pseudo Labeling : 814
# [155/3000] Train Acc: 0.857433 Loss: 0.336980 | Val Acc: 0.456174 loss: 1.655687
# Pseudo Labeling : 872
# [156/3000] Train Acc: 0.860185 Loss: 0.325057 | Val Acc: 0.454268 loss: 1.704160
# Pseudo Labeling : 836
# [157/3000] Train Acc: 0.862565 Loss: 0.326204 | Val Acc: 0.456174 loss: 1.727366
# Pseudo Labeling : 826
# [158/3000] Train Acc: 0.858291 Loss: 0.331250 | Val Acc: 0.469131 loss: 1.639886
# Pseudo Labeling : 816
# [159/3000] Train Acc: 0.859581 Loss: 0.324903 | Val Acc: 0.466082 loss: 1.661527
# Pseudo Labeling : 834
# [160/3000] Train Acc: 0.858127 Loss: 0.329955 | Val Acc: 0.463034 loss: 1.665015
# Pseudo Labeling : 849
# [161/3000] Train Acc: 0.862282 Loss: 0.329097 | Val Acc: 0.460747 loss: 1.678606
# Pseudo Labeling : 805
# [162/3000] Train Acc: 0.864224 Loss: 0.319501 | Val Acc: 0.463796 loss: 1.673855
# Pseudo Labeling : 844
# [163/3000] Train Acc: 0.863721 Loss: 0.324368 | Val Acc: 0.462652 loss: 1.656317
# Pseudo Labeling : 840
# [164/3000] Train Acc: 0.864820 Loss: 0.326133 | Val Acc: 0.452363 loss: 1.719039
# Pseudo Labeling : 822
# [165/3000] Train Acc: 0.861953 Loss: 0.323033 | Val Acc: 0.462271 loss: 1.640030
# Pseudo Labeling : 832
# [166/3000] Train Acc: 0.859956 Loss: 0.323863 | Val Acc: 0.471799 loss: 1.693197
# Pseudo Labeling : 830
# [167/3000] Train Acc: 0.864259 Loss: 0.319306 | Val Acc: 0.465701 loss: 1.671513
# Pseudo Labeling : 834
# [168/3000] Train Acc: 0.860334 Loss: 0.325706 | Val Acc: 0.471418 loss: 1.663347
# Pseudo Labeling : 812
# [169/3000] Train Acc: 0.859885 Loss: 0.327532 | Val Acc: 0.467988 loss: 1.672208
# Pseudo Labeling : 839
# [170/3000] Train Acc: 0.863572 Loss: 0.326303 | Val Acc: 0.461509 loss: 1.739510
# Pseudo Labeling : 806
# [171/3000] Train Acc: 0.863351 Loss: 0.321324 | Val Acc: 0.469893 loss: 1.652840
# Pseudo Labeling : 800
# [172/3000] Train Acc: 0.862835 Loss: 0.325318 | Val Acc: 0.467607 loss: 1.653465
# Pseudo Labeling : 820
# [173/3000] Train Acc: 0.862724 Loss: 0.318098 | Val Acc: 0.471037 loss: 1.673135
# Pseudo Labeling : 843
# [174/3000] Train Acc: 0.863973 Loss: 0.322046 | Val Acc: 0.472942 loss: 1.591837
# Pseudo Labeling : 844
# [175/3000] Train Acc: 0.863897 Loss: 0.327025 | Val Acc: 0.477896 loss: 1.607531
# Pseudo Labeling : 852
# [176/3000] Train Acc: 0.862935 Loss: 0.323490 | Val Acc: 0.472180 loss: 1.603899
# Pseudo Labeling : 848
# [177/3000] Train Acc: 0.866149 Loss: 0.322962 | Val Acc: 0.466463 loss: 1.660232
# Pseudo Labeling : 843
# [178/3000] Train Acc: 0.866531 Loss: 0.318663 | Val Acc: 0.472180 loss: 1.625109
# Pseudo Labeling : 825
# [179/3000] Train Acc: 0.863757 Loss: 0.319920 | Val Acc: 0.466082 loss: 1.677456
# Pseudo Labeling : 823
# [180/3000] Train Acc: 0.860817 Loss: 0.320604 | Val Acc: 0.471799 loss: 1.652291
# Pseudo Labeling : 836
# [181/3000] Train Acc: 0.864860 Loss: 0.321729 | Val Acc: 0.480183 loss: 1.611010
# Pseudo Labeling : 838
# [182/3000] Train Acc: 0.860471 Loss: 0.326854 | Val Acc: 0.467988 loss: 1.648956
# Pseudo Labeling : 864
# [183/3000] Train Acc: 0.864225 Loss: 0.319860 | Val Acc: 0.466845 loss: 1.706070
# Pseudo Labeling : 833
# [184/3000] Train Acc: 0.863500 Loss: 0.320226 | Val Acc: 0.468750 loss: 1.657723
# Pseudo Labeling : 839
# [185/3000] Train Acc: 0.865867 Loss: 0.321935 | Val Acc: 0.468369 loss: 1.666559
# Pseudo Labeling : 875
# [186/3000] Train Acc: 0.864708 Loss: 0.324453 | Val Acc: 0.458460 loss: 1.690093
# Pseudo Labeling : 836
# [187/3000] Train Acc: 0.864507 Loss: 0.320534 | Val Acc: 0.474085 loss: 1.628927
# Pseudo Labeling : 868
# [188/3000] Train Acc: 0.864008 Loss: 0.317536 | Val Acc: 0.471037 loss: 1.648023
# Pseudo Labeling : 891
# [189/3000] Train Acc: 0.862790 Loss: 0.317971 | Val Acc: 0.474466 loss: 1.633278
# Pseudo Labeling : 834
# [190/3000] Train Acc: 0.861128 Loss: 0.318399 | Val Acc: 0.470274 loss: 1.656581
# Pseudo Labeling : 855
# [191/3000] Train Acc: 0.868787 Loss: 0.310765 | Val Acc: 0.481326 loss: 1.614375
# Pseudo Labeling : 853
# [192/3000] Train Acc: 0.864798 Loss: 0.318672 | Val Acc: 0.475991 loss: 1.636851
# Pseudo Labeling : 887
# [193/3000] Train Acc: 0.859842 Loss: 0.318698 | Val Acc: 0.475610 loss: 1.649642
# Pseudo Labeling : 856
# [194/3000] Train Acc: 0.865010 Loss: 0.315854 | Val Acc: 0.466845 loss: 1.660430
# Pseudo Labeling : 844
# [195/3000] Train Acc: 0.865044 Loss: 0.316315 | Val Acc: 0.468750 loss: 1.681905
# Pseudo Labeling : 861
# [196/3000] Train Acc: 0.866479 Loss: 0.316961 | Val Acc: 0.471037 loss: 1.648941
# Pseudo Labeling : 847
# [197/3000] Train Acc: 0.865256 Loss: 0.320979 | Val Acc: 0.474466 loss: 1.626631
# Pseudo Labeling : 846
# [198/3000] Train Acc: 0.865508 Loss: 0.316759 | Val Acc: 0.472561 loss: 1.672046
# Pseudo Labeling : 845
# [199/3000] Train Acc: 0.866290 Loss: 0.316255 | Val Acc: 0.469512 loss: 1.680716
# Pseudo Labeling : 862
# [200/3000] Train Acc: 0.866931 Loss: 0.313288 | Val Acc: 0.464939 loss: 1.674065
# Pseudo Labeling : 873
# [201/3000] Train Acc: 0.863804 Loss: 0.318903 | Val Acc: 0.479421 loss: 1.615653
# Pseudo Labeling : 898
# [202/3000] Train Acc: 0.859802 Loss: 0.316758 | Val Acc: 0.476372 loss: 1.638164
# Pseudo Labeling : 851
# [203/3000] Train Acc: 0.870240 Loss: 0.309925 | Val Acc: 0.474466 loss: 1.620005
# Pseudo Labeling : 878
# [204/3000] Train Acc: 0.863512 Loss: 0.315654 | Val Acc: 0.469893 loss: 1.673350
# Pseudo Labeling : 878
# [205/3000] Train Acc: 0.862545 Loss: 0.319261 | Val Acc: 0.471799 loss: 1.666408
# Pseudo Labeling : 841
# [206/3000] Train Acc: 0.868008 Loss: 0.316138 | Val Acc: 0.473323 loss: 1.653709
# Pseudo Labeling : 858
# [207/3000] Train Acc: 0.864505 Loss: 0.316354 | Val Acc: 0.459604 loss: 1.697572
# Pseudo Labeling : 857
# [208/3000] Train Acc: 0.865991 Loss: 0.312248 | Val Acc: 0.471799 loss: 1.666219
# Pseudo Labeling : 877
# [209/3000] Train Acc: 0.866403 Loss: 0.312774 | Val Acc: 0.472942 loss: 1.646325
# Pseudo Labeling : 865
# [210/3000] Train Acc: 0.864941 Loss: 0.314342 | Val Acc: 0.475229 loss: 1.647034
# Pseudo Labeling : 862
# [211/3000] Train Acc: 0.866138 Loss: 0.314109 | Val Acc: 0.467988 loss: 1.703185
# Pseudo Labeling : 846
# [212/3000] Train Acc: 0.868331 Loss: 0.314573 | Val Acc: 0.468750 loss: 1.680581
# Pseudo Labeling : 848
# [213/3000] Train Acc: 0.869588 Loss: 0.310292 | Val Acc: 0.470655 loss: 1.657042
# Pseudo Labeling : 873
# [214/3000] Train Acc: 0.865476 Loss: 0.316022 | Val Acc: 0.471037 loss: 1.654816
# Pseudo Labeling : 859
# [215/3000] Train Acc: 0.868041 Loss: 0.312467 | Val Acc: 0.475991 loss: 1.640143
# Pseudo Labeling : 846
# [216/3000] Train Acc: 0.868331 Loss: 0.310410 | Val Acc: 0.471037 loss: 1.657637
# Pseudo Labeling : 877
# [217/3000] Train Acc: 0.864908 Loss: 0.319241 | Val Acc: 0.480183 loss: 1.609673
# Pseudo Labeling : 872
# [218/3000] Train Acc: 0.866344 Loss: 0.315681 | Val Acc: 0.479802 loss: 1.612985
# Pseudo Labeling : 870
# [219/3000] Train Acc: 0.865880 Loss: 0.311762 | Val Acc: 0.483994 loss: 1.600376
# Pseudo Labeling : 869
# [220/3000] Train Acc: 0.865869 Loss: 0.312172 | Val Acc: 0.472942 loss: 1.639115
# Pseudo Labeling : 874
# [221/3000] Train Acc: 0.864520 Loss: 0.314019 | Val Acc: 0.481326 loss: 1.576982
# Pseudo Labeling : 852
# [222/3000] Train Acc: 0.866020 Loss: 0.317715 | Val Acc: 0.463034 loss: 1.716943
# Pseudo Labeling : 847
# [223/3000] Train Acc: 0.867108 Loss: 0.316394 | Val Acc: 0.475610 loss: 1.629690
# Pseudo Labeling : 844
# [224/3000] Train Acc: 0.866543 Loss: 0.317357 | Val Acc: 0.465320 loss: 1.701360
# Pseudo Labeling : 861
# [225/3000] Train Acc: 0.865686 Loss: 0.313833 | Val Acc: 0.464177 loss: 1.713377
# Pseudo Labeling : 861
# [226/3000] Train Acc: 0.863484 Loss: 0.314368 | Val Acc: 0.475991 loss: 1.641450
# Pseudo Labeling : 864
# [227/3000] Train Acc: 0.866866 Loss: 0.316223 | Val Acc: 0.469893 loss: 1.677544
# Pseudo Labeling : 853
# [228/3000] Train Acc: 0.867002 Loss: 0.313547 | Val Acc: 0.466082 loss: 1.670029
# Pseudo Labeling : 867
# [229/3000] Train Acc: 0.866725 Loss: 0.313837 | Val Acc: 0.474466 loss: 1.669336
# Pseudo Labeling : 893
# [230/3000] Train Acc: 0.865010 Loss: 0.308664 | Val Acc: 0.478277 loss: 1.623583
# Pseudo Labeling : 883
# [231/3000] Train Acc: 0.866473 Loss: 0.315154 | Val Acc: 0.475991 loss: 1.640518
# Pseudo Labeling : 877
# [232/3000] Train Acc: 0.867458 Loss: 0.311772 | Val Acc: 0.471418 loss: 1.645793
# Pseudo Labeling : 866
# [233/3000] Train Acc: 0.865921 Loss: 0.313482 | Val Acc: 0.480945 loss: 1.594516
# Pseudo Labeling : 871
# [234/3000] Train Acc: 0.865628 Loss: 0.314699 | Val Acc: 0.467988 loss: 1.661609
# Pseudo Labeling : 841
# [235/3000] Train Acc: 0.871449 Loss: 0.309673 | Val Acc: 0.470655 loss: 1.638006
# Pseudo Labeling : 844
# [236/3000] Train Acc: 0.868572 Loss: 0.315697 | Val Acc: 0.468750 loss: 1.663956
# Pseudo Labeling : 869
# [237/3000] Train Acc: 0.865341 Loss: 0.316985 | Val Acc: 0.466463 loss: 1.673602
# Pseudo Labeling : 853
# [238/3000] Train Acc: 0.870263 Loss: 0.309408 | Val Acc: 0.474466 loss: 1.630711
# Pseudo Labeling : 858
# [239/3000] Train Acc: 0.868558 Loss: 0.310973 | Val Acc: 0.481707 loss: 1.610797
# Pseudo Labeling : 875
# [240/3000] Train Acc: 0.870338 Loss: 0.309569 | Val Acc: 0.475229 loss: 1.622581
# Pseudo Labeling : 864
# [241/3000] Train Acc: 0.866426 Loss: 0.313216 | Val Acc: 0.469512 loss: 1.682974
# Pseudo Labeling : 894
# [242/3000] Train Acc: 0.865724 Loss: 0.311295 | Val Acc: 0.477134 loss: 1.633627
# Pseudo Labeling : 895
# [243/3000] Train Acc: 0.868282 Loss: 0.312670 | Val Acc: 0.480945 loss: 1.587919

# %%
print(f'Training use {round(end_time - start_time, 3)}s')
# Out:
# Training use 189.517s

# %%
def plot_learning_curve(train_record, valid_record, title=''):
    total_steps = len(train_record)
    x = range(total_steps)
    plt.figure(figsize=(6, 4))
    plt.plot(x, train_record, c='tab:red', label='train')
    plt.plot(x, valid_record, c='tab:cyan', label='valid')
    plt.ylim(0.0, max(valid_record) + 1)
    plt.xlabel('Training epoch')
    plt.ylabel(title)
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()

# %%
plot_learning_curve(train_acc_list, val_acc_list, 'Acc')

# %%
plot_learning_curve(train_loss_list, val_loss_list, 'Loss')

# %%
model = Classifier().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))

model.eval() # set the model to evaluation mode
train_predict = []
err = 0
for i, data in enumerate(train_loader):
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)
    outputs = model(inputs)
    _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

    for y in test_pred.cpu().numpy():
        train_predict.append(y)

Ein = np.mean(np.array(train_predict) != train_y)
F1in = metrics.f1_score(train_y, train_predict, average='macro')  
print(f'Ein = {round(Ein, 5)}')
print(f'F1_in = {round(F1in, 5)}')

val_predict = []
for i, data in enumerate(val_loader):
    inputs = data[0]
    inputs = inputs.to(device)
    outputs = model(inputs)
    _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

    for y in test_pred.cpu().numpy():
        val_predict.append(y)

Eval = np.mean(np.array(val_predict) != val_y)
F1val = metrics.f1_score(val_y, val_predict, average='macro')  
print(f'Eval = {round(Eval, 5)}')
print(f'F1_val = {round(F1val, 5)}')
# Out:
# Ein = 0.78452
# F1_in = 0.16152
# Eval = 0.48438
# F1_val = 0.2164

# %% [markdown]
# # **Deep Neural Network Test**

# %%
# create testing dataset
test_set = IBMDataset(X_test_std, None)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# create model and load weights from checkpoint
model = Classifier().to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
predict = []
model.eval() # set the model to evaluation mode
for i, data in enumerate(test_loader):
    inputs = data
    inputs = inputs.to(device)
    outputs = model(inputs)
    _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

    for y in test_pred.cpu().numpy():
        predict.append(y)

print(encoder_map)
print(np.bincount(predict))
# Out:
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}
# [  61  169   79 1055   20   25]

# %%
dnn_submit_result = './dnn_result.csv'

new_encoder_map = {'No Churn':0, 'Competitor': 1, 'Dissatisfaction':2, 'Attitude': 3, 'Price':4, 'Other':5}

with open(dnn_submit_result, 'w') as f:
    f.write('Customer ID,Churn Category\n')
    for i in range(len(df_test.values)):
        id = str(df_test.values[i]).replace('[\'', '')
        id = id.replace('\']', '')
        pred = new_encoder_map.get(list(encoder_map.keys())[list(encoder_map.values()).index(predict[i])])
        f.write(f'{id},{pred}\n')

# %%
from google.colab import files

files.download(dnn_submit_result)
files.download(model_path)

# %% [markdown]
# # **XGBoost Train**

# %%
train_x, train_y, val_x, val_y = X_train[:percent], y_train[:percent], X_train[percent:], y_train[percent:]

ss = StandardScaler().fit(train_x)
train_x = ss.transform(train_x)
miss_x = ss.transform(X_train_miss)
val_x = ss.transform(val_x)
X_test_std = ss.transform(X_test)

# %%
classifier = XGBClassifier(
    learning_rate =0.3,
    n_estimators=20,
    max_depth=10,
    min_child_weight=1,
    gamma=0,
    subsample=0.5,
    colsample_bytree=0.8,
    scale_pos_weight=1,
    use_label_encoder =False,
    eval_metric='mlogloss')

# %%
start_time = time.time()
model = classifier.fit(train_x, train_y)
end_time = time.time()

train_predict = model.predict(train_x)
val_predict = model.predict(val_x)

# %%
print(f'Training use {round(end_time - start_time, 3)}s')
# Out:
# Training use 2.868s

# %%
Ein = np.mean(np.array(train_predict) != train_y)
F1in = metrics.f1_score(train_y, train_predict, average='macro')  
print(f'Ein = {round(Ein, 5)}')
print(f'F1_in = {round(F1in, 5)}')
print('XGBoost Train Score {}'.format(model.score(train_x, train_y)))
print()

Eval = np.mean(np.array(val_predict) != val_y)
F1val = metrics.f1_score(val_y, val_predict, average='macro')  
print(f'Eval = {round(Eval, 5)}')
print(f'F1_val = {round(F1val, 5)}')
print('XGBoost Valid Score {}'.format(model.score(val_x, val_y)))
# Out:
# Ein = 0.10903
# F1_in = 0.82793
# XGBoost Train Score 0.8909749356714
#
# Eval = 0.73285
# F1_val = 0.14148
# XGBoost Valid Score 0.26714939024390244

# %% [markdown]
# # **XGBoost Test**

# %%
predict = model.predict(X_test_std)
predict = np.array(predict, dtype=np.int64)

print(encoder_map)
print(np.bincount(predict))
# Out:
# {'Attitude': 0, 'Competitor': 1, 'Dissatisfaction': 2, 'No Churn': 3, 'Other': 4, 'Price': 5}
# [  51  197   31 1115    9    6]

# %%
xgboost_submit_result = './xgboost_result.csv'

new_encoder_map = {'No Churn':0, 'Competitor': 1, 'Dissatisfaction':2, 'Attitude': 3, 'Price':4, 'Other':5}

with open(xgboost_submit_result, 'w') as f:
    f.write('Customer ID,Churn Category\n')
    for i in range(len(df_test.values)):
        id = str(df_test.values[i]).replace('[\'', '')
        id = id.replace('\']', '')
        pred = new_encoder_map.get(list(encoder_map.keys())[list(encoder_map.values()).index(predict[i])])
        f.write(f'{id},{pred}\n')

# %%
from google.colab import files

files.download(xgboost_submit_result)

# %% [markdown]
# # **Test Data Analysis**

# %%
svm_test = pd.read_csv(svm_submit_result)
dnn_test = pd.read_csv(dnn_submit_result)
xgboost_test = pd.read_csv(xgboost_submit_result)

# %%
def plotResult(dataset1, dataset2, dataset3, method):
    fig, ax = plt.subplots(1, 3, figsize=(16, 6))
    fig.suptitle('Test Data Statistics')

    counts = []
    iter = 0
    for dataset in [dataset1, dataset2, dataset3]:
        freq = dataset.groupby('Churn Category').size()
        print(f'====== {method[iter]} ======')
        print(freq)
        print()

        counts = [count for _, count in freq.items()]
        x = np.arange(len(counts))
        ax[iter].bar(x, counts)
        ax[iter].set_xticks([0, 1, 2, 3, 4, 5])
        ax[iter].set_xticklabels(['No Churn', 'Competitor', 'Dissatisfaction', 'Attitude', 'Price', 'Other'], rotation=90)
        ax[iter].set_title(f'{method[iter]}')
        iter += 1

    plt.show()

# %%
plotResult(svm_test, dnn_test, xgboost_test, ['SVM', 'DNN', 'XGBoost'])
# Out:
# ====== SVM ======
# Churn Category
# 0    1019
# 1     193
# 2      67
# 3      80
# 4      35
# 5      15
# dtype: int64
#
# ====== DNN ======
# Churn Category
# 0    1055
# 1     169
# 2      79
# 3      61
# 4      25
# 5      20
# dtype: int64
#
# ====== XGBoost ======
# Churn Category
# 0    1115
# 1     197
# 2      31
# 3      51
# 4       6
# 5       9
# dtype: int64
